# %% [markdown]
# # Cleaning Covid data for Mapbox: regions
#
# **Background**: We use Covid-19 cases data in the Philippines from data from the health department and shapefile processed through geopandas to create an interactive map.
#
# **Tools**: pandas, geopandas, Mapbox
#
# Updated: May 6, 2023

# %% [markdown]
# # Do your imports

# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import re
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Read your CSV

# %%
df= pd.read_csv('../data/regions.csv')
df
# Out:
#                              index  RegionRes
# 0                              NCR    1320482
# 1          Region IV-A: CALABARZON     732170
# 2        Region III: Central Luzon     402291
# 3       Region VI: Western Visayas     219393
# 4      Region VII: Central Visayas     210626
# 5        Region II: Cagayan Valley     175239
# 6          Region XI: Davao Region     156723
# 7          Region I: Ilocos Region     147288
# 8                              CAR     130358
# 9      Region X: Northern Mindanao     115136
# 10        Region XII: SOCCSKSARGEN      85634
# 11          Region V: Bicol Region      73891
# 12  Region IX: Zamboanga Peninsula      71045
# 13    Region VIII: Eastern Visayas      67937
# 14                          CARAGA      67345
# 15           Region IV-B: MIMAROPA      48312
# 16                             ROF      42797
# 17                           BARMM      28543
# 18                             NaN       3878

# %% [markdown]
# ## Lowercase column headers

# %%
df.columns = df.columns.str.lower()
df.head()
# Out:
#                          index  regionres
# 0                          NCR    1320482
# 1      Region IV-A: CALABARZON     732170
# 2    Region III: Central Luzon     402291
# 3   Region VI: Western Visayas     219393
# 4  Region VII: Central Visayas     210626

# %%
df= df.rename(columns={"regionres": "covid_cases"})
df= df.rename(columns={"index": "regions"})
df.head(18)
# Out:
#                            regions  covid_cases
# 0                              NCR      1320482
# 1          Region IV-A: CALABARZON       732170
# 2        Region III: Central Luzon       402291
# 3       Region VI: Western Visayas       219393
# 4      Region VII: Central Visayas       210626
# 5        Region II: Cagayan Valley       175239
# 6          Region XI: Davao Region       156723
# 7          Region I: Ilocos Region       147288
# 8                              CAR       130358
# 9      Region X: Northern Mindanao       115136
# 10        Region XII: SOCCSKSARGEN        85634
# 11          Region V: Bicol Region        73891
# 12  Region IX: Zamboanga Peninsula        71045
# 13    Region VIII: Eastern Visayas        67937
# 14                          CARAGA        67345
# 15           Region IV-B: MIMAROPA        48312
# 16                             ROF        42797
# 17                           BARMM        28543

# %% [markdown]
# # Geopandas
#
# ## Read through file

# %%
region_shape = gpd.read_file('regions.zip')
region_shape
# Out:
#     Shape_Leng  Shape_Area                                          ADM1_EN  \
# 0    53.623497    1.050272  Bangsamoro Autonomous Region in Muslim Mindanao
# 1     8.027454    1.546712                 Cordillera Administrative Region
# 2     2.320234    0.050216                          National Capital Region
# 3    14.995101    1.043983                                         Region I
# 4    19.139048    2.241812                                        Region II
# 5    15.949563    1.793513                                       Region III
# 6    27.624115    1.326710                                      Region IV-A
# 7    78.804542    2.220374                                      Region IV-B
# 8    23.181441    1.196677                                        Region IX
# 9    44.923243    1.446324                                         Region V
# 10   27.589382    1.657135                                        Region VI
# 11   29.113105    1.178431                                       Region VII
# 12   42.021179    1.726804                                      Region VIII
# 13   15.002953    1.435115                                         Region X
# 14   17.934222    1.539971                                        Region XI
# 15   13.229749    1.471068                                       Region XII
# 16   28.166754    1.540820                                      Region XIII
#
#      ADM1_PCODE ADM1_REF           ADM1ALT1EN ADM1ALT2EN            ADM0_EN  \
# 0   PH150000000     None                BARMM       None  Philippines (the)
# 1   PH140000000     None                  CAR       None  Philippines (the)
# 2   PH130000000     None                  NCR       None  Philippines (the)
# 3   PH010000000     None        Ilocos Region       None  Philippines (the)
# 4   PH020000000     None       Cagayan Valley       None  Philippines (the)
# 5   PH030000000     None        Central Luzon       None  Philippines (the)
# 6   PH040000000     None           Calabarzon       None  Philippines (the)
# 7   PH170000000     None             Mimaropa       None  Philippines (the)
# 8   PH090000000     None  Zamboanga Peninsula       None  Philippines (the)
# 9   PH050000000     None         Bicol Region       None  Philippines (the)
# 10  PH060000000     None      Western Visayas       None  Philippines (the)
# 11  PH070000000     None      Central Visayas       None  Philippines (the)
# 12  PH080000000     None      Eastern Visayas       None  Philippines (the)
# 13  PH100000000     None    Northern Mindanao       None  Philippines (the)
# 14  PH110000000     None         Davao Region       None  Philippines (the)
# 15  PH120000000     None         Soccsksargen       None  Philippines (the)
# 16  PH160000000     None               Caraga       None  Philippines (the)
#
#    ADM0_PCODE        date     validOn validTo  \
# 0          PH  2016-06-30  2020-05-29    None
# 1          PH  2016-06-30  2020-05-29    None
# 2          PH  2016-06-30  2020-05-29    None
# 3          PH  2016-06-30  2020-05-29    None
# 4          PH  2016-06-30  2020-05-29    None
# 5          PH  2016-06-30  2020-05-29    None
# 6          PH  2016-06-30  2020-05-29    None
# 7          PH  2016-06-30  2020-05-29    None
# 8          PH  2016-06-30  2020-05-29    None
# 9          PH  2016-06-30  2020-05-29    None
# 10         PH  2016-06-30  2020-05-29    None
# 11         PH  2016-06-30  2020-05-29    None
# 12         PH  2016-06-30  2020-05-29    None
# 13         PH  2016-06-30  2020-05-29    None
# 14         PH  2016-06-30  2020-05-29    None
# 15         PH  2016-06-30  2020-05-29    None
# 16         PH  2016-06-30  2020-05-29    None
#
#                                              geometry
# 0   MULTIPOLYGON (((119.46876 4.59360, 119.46881 4...
# 1   POLYGON ((121.22208 18.50058, 121.22086 18.483...
# 2   POLYGON ((121.03842 14.78525, 121.03876 14.785...
# 3   MULTIPOLYGON (((119.86596 15.81539, 119.86597 ...
# 4   MULTIPOLYGON (((122.46667 16.92135, 122.46674 ...
# 5   MULTIPOLYGON (((120.11687 14.76309, 120.11689 ...
# 6   MULTIPOLYGON (((122.72165 13.36485, 122.72181 ...
# 7   MULTIPOLYGON (((117.31260 7.50671, 117.31249 7...
# 8   MULTIPOLYGON (((121.88379 6.69138, 121.88380 6...
# 9   MULTIPOLYGON (((122.98823 11.73079, 122.98824 ...
# 10  MULTIPOLYGON (((122.49684 9.55607, 122.49685 9...
# 11  MULTIPOLYGON (((123.27039 9.08460, 123.27040 9...
# 12  MULTIPOLYGON (((125.06042 9.96466, 125.06043 9...
# 13  MULTIPOLYGON (((123.57503 8.63343, 123.57462 8...
# 14  MULTIPOLYGON (((125.39719 5.43791, 125.39719 5...
# 15  MULTIPOLYGON (((124.24158 7.26286, 124.24233 7...
# 16  MULTIPOLYGON (((126.34198 8.87710, 126.34167 8...

# %% [markdown]
# ## Clean regional names in the dataset
#
# This is so they would match the names in the shapefile for merging later.

# %%
df.regions = df.regions.str.replace("NCR", "National Capital Region", regex=False)
df.regions = df.regions.str.replace("BARMM", "Bangsamoro Autonomous Region in Muslim Mindanao", regex=False)
df.regions = df.regions.str.replace("CAR", "Cordillera Administrative Region", regex=False)
df.regions = df.regions.str.replace("Cordillera Administrative RegionAGA", "Region XIII", regex=False)
df.regions = df.regions.str.replace(r'[:].*$', "", regex=True)
df.regions
# Out:
# 0                             National Capital Region
# 1                                         Region IV-A
# 2                                          Region III
# 3                                           Region VI
# 4                                          Region VII
# 5                                           Region II
# 6                                           Region XI
# 7                                            Region I
# 8                    Cordillera Administrative Region
# 9                                            Region X
# 10                                         Region XII
# 11                                           Region V
# 12                                          Region IX
# 13                                        Region VIII
# 14                                        Region XIII
# 15                                        Region IV-B
# 16                                                ROF
# 17    Bangsamoro Autonomous Region in Muslim Mindanao
# 18                                                NaN
# Name: regions, dtype: object

# %% [markdown]
# ## Clean the shapefile

# %% [markdown]
# ### Drop unnecessary columns from shapefile

# %%
region_shape = region_shape.drop(['ADM0_PCODE', 'ADM0_EN','date','validOn','validTo', 'ADM1_PCODE', 'ADM1ALT2EN', 'ADM1_REF'], axis=1)
region_shape
# Out:
#     Shape_Leng  Shape_Area                                          ADM1_EN  \
# 0    53.623497    1.050272  Bangsamoro Autonomous Region in Muslim Mindanao
# 1     8.027454    1.546712                 Cordillera Administrative Region
# 2     2.320234    0.050216                          National Capital Region
# 3    14.995101    1.043983                                         Region I
# 4    19.139048    2.241812                                        Region II
# 5    15.949563    1.793513                                       Region III
# 6    27.624115    1.326710                                      Region IV-A
# 7    78.804542    2.220374                                      Region IV-B
# 8    23.181441    1.196677                                        Region IX
# 9    44.923243    1.446324                                         Region V
# 10   27.589382    1.657135                                        Region VI
# 11   29.113105    1.178431                                       Region VII
# 12   42.021179    1.726804                                      Region VIII
# 13   15.002953    1.435115                                         Region X
# 14   17.934222    1.539971                                        Region XI
# 15   13.229749    1.471068                                       Region XII
# 16   28.166754    1.540820                                      Region XIII
#
#              ADM1ALT1EN                                           geometry
# 0                 BARMM  MULTIPOLYGON (((119.46876 4.59360, 119.46881 4...
# 1                   CAR  POLYGON ((121.22208 18.50058, 121.22086 18.483...
# 2                   NCR  POLYGON ((121.03842 14.78525, 121.03876 14.785...
# 3         Ilocos Region  MULTIPOLYGON (((119.86596 15.81539, 119.86597 ...
# 4        Cagayan Valley  MULTIPOLYGON (((122.46667 16.92135, 122.46674 ...
# 5         Central Luzon  MULTIPOLYGON (((120.11687 14.76309, 120.11689 ...
# 6            Calabarzon  MULTIPOLYGON (((122.72165 13.36485, 122.72181 ...
# 7              Mimaropa  MULTIPOLYGON (((117.31260 7.50671, 117.31249 7...
# 8   Zamboanga Peninsula  MULTIPOLYGON (((121.88379 6.69138, 121.88380 6...
# 9          Bicol Region  MULTIPOLYGON (((122.98823 11.73079, 122.98824 ...
# 10      Western Visayas  MULTIPOLYGON (((122.49684 9.55607, 122.49685 9...
# 11      Central Visayas  MULTIPOLYGON (((123.27039 9.08460, 123.27040 9...
# 12      Eastern Visayas  MULTIPOLYGON (((125.06042 9.96466, 125.06043 9...
# 13    Northern Mindanao  MULTIPOLYGON (((123.57503 8.63343, 123.57462 8...
# 14         Davao Region  MULTIPOLYGON (((125.39719 5.43791, 125.39719 5...
# 15         Soccsksargen  MULTIPOLYGON (((124.24158 7.26286, 124.24233 7...
# 16               Caraga  MULTIPOLYGON (((126.34198 8.87710, 126.34167 8...

# %%
region_shape= region_shape.rename(columns={"ADM1_EN": "regions"})

# %% [markdown]
# ## Merge data

# %%
regions_cases = region_shape.merge(df, on='regions')
regions_cases.head()
# Out:
#    Shape_Leng  Shape_Area                                          regions  \
# 0   53.623497    1.050272  Bangsamoro Autonomous Region in Muslim Mindanao
# 1    8.027454    1.546712                 Cordillera Administrative Region
# 2    2.320234    0.050216                          National Capital Region
# 3   14.995101    1.043983                                         Region I
# 4   19.139048    2.241812                                        Region II
#
#        ADM1ALT1EN                                           geometry  \
# 0           BARMM  MULTIPOLYGON (((119.46876 4.59360, 119.46881 4...
# 1             CAR  POLYGON ((121.22208 18.50058, 121.22086 18.483...
# 2             NCR  POLYGON ((121.03842 14.78525, 121.03876 14.785...
# 3   Ilocos Region  MULTIPOLYGON (((119.86596 15.81539, 119.86597 ...
# 4  Cagayan Valley  MULTIPOLYGON (((122.46667 16.92135, 122.46674 ...
#
#    covid_cases
# 0        28543
# 1       130358
# 2      1320482
# 3       147288
# 4       175239

# %% [markdown]
# ## Read and merge with population data

# %%
df2 = pd.read_excel('population.xlsx')
df2.head()
# Out:
#                             regions  population
# 0           National Capital Region    12877253
# 1  Cordillera Administrative Region     1797660
# 2                          Region I     5026128
# 3                         Region II     3685744
# 4                        Region III    12422172

# %%
regions_final = regions_cases.merge(df2, on='regions')
regions_final.head()
# Out:
#    Shape_Leng  Shape_Area                                          regions  \
# 0   53.623497    1.050272  Bangsamoro Autonomous Region in Muslim Mindanao
# 1    8.027454    1.546712                 Cordillera Administrative Region
# 2    2.320234    0.050216                          National Capital Region
# 3   14.995101    1.043983                                         Region I
# 4   19.139048    2.241812                                        Region II
#
#        ADM1ALT1EN                                           geometry  \
# 0           BARMM  MULTIPOLYGON (((119.46876 4.59360, 119.46881 4...
# 1             CAR  POLYGON ((121.22208 18.50058, 121.22086 18.483...
# 2             NCR  POLYGON ((121.03842 14.78525, 121.03876 14.785...
# 3   Ilocos Region  MULTIPOLYGON (((119.86596 15.81539, 119.86597 ...
# 4  Cagayan Valley  MULTIPOLYGON (((122.46667 16.92135, 122.46674 ...
#
#    covid_cases  population
# 0        28543     4404288
# 1       130358     1797660
# 2      1320482    12877253
# 3       147288     5026128
# 4       175239     3685744

# %% [markdown]
# ## Compute for population ratio
#
# We do this by dividing the number of Covid-19 cases to total population per region and then multiply by 100,000. That would give us cases per 100,000 people in the area.

# %%
regions_final ['case_per_pop'] = regions_final.covid_cases / regions_final.population * 100000
regions_final = regions_final.round(1)

# %% [markdown]
# ## Create bins for cases
#
# The bins will allow us to categorize the number of cases, necessary for mapping later.

# %%
regions_final['percentiles'] = pd.cut(np.array(regions_final['case_per_pop']),
   [0, 1001, 2001, 3001, 4001, 5001, 6001, 7001, 8001, 9001, 10001, 11000], labels=["0-1000", "1001-2000", "2001-3000", "3001-4000", "4001-5000", "5001-6000", "6001-7000", "7001-8000", "8001-9000", "9001-10000", "10001-11000"])

regions_final.head()
# Out:
#    Shape_Leng  Shape_Area                                          regions  \
# 0        53.6         1.1  Bangsamoro Autonomous Region in Muslim Mindanao
# 1         8.0         1.5                 Cordillera Administrative Region
# 2         2.3         0.1                          National Capital Region
# 3        15.0         1.0                                         Region I
# 4        19.1         2.2                                        Region II
#
#        ADM1ALT1EN                                           geometry  \
# 0           BARMM  MULTIPOLYGON (((119.46876 4.59360, 119.46881 4...
# 1             CAR  POLYGON ((121.22208 18.50058, 121.22086 18.483...
# 2             NCR  POLYGON ((121.03842 14.78525, 121.03876 14.785...
# 3   Ilocos Region  MULTIPOLYGON (((119.86596 15.81539, 119.86597 ...
# 4  Cagayan Valley  MULTIPOLYGON (((122.46667 16.92135, 122.46674 ...
#
#    covid_cases  population  case_per_pop  percentiles
# 0        28543     4404288         648.1       0-1000
# 1       130358     1797660        7251.5    7001-8000
# 2      1320482    12877253       10254.4  10001-11000
# 3       147288     5026128        2930.4    2001-3000
# 4       175239     3685744        4754.5    4001-5000

# %%
regions_final.sort_values('case_per_pop', ascending=False)
# Out:
#     Shape_Leng  Shape_Area                                          regions  \
# 2          2.3         0.1                          National Capital Region
# 1          8.0         1.5                 Cordillera Administrative Region
# 4         19.1         2.2                                        Region II
# 6         27.6         1.3                                      Region IV-A
# 5         15.9         1.8                                       Region III
# 14        17.9         1.5                                        Region XI
# 3         15.0         1.0                                         Region I
# 10        27.6         1.7                                        Region VI
# 11        29.1         1.2                                       Region VII
# 16        28.2         1.5                                      Region XIII
# 13        15.0         1.4                                         Region X
# 8         23.2         1.2                                        Region IX
# 15        13.2         1.5                                       Region XII
# 7         78.8         2.2                                      Region IV-B
# 12        42.0         1.7                                      Region VIII
# 9         44.9         1.4                                         Region V
# 0         53.6         1.1  Bangsamoro Autonomous Region in Muslim Mindanao
#
#              ADM1ALT1EN                                           geometry  \
# 2                   NCR  POLYGON ((121.03842 14.78525, 121.03876 14.785...
# 1                   CAR  POLYGON ((121.22208 18.50058, 121.22086 18.483...
# 4        Cagayan Valley  MULTIPOLYGON (((122.46667 16.92135, 122.46674 ...
# 6            Calabarzon  MULTIPOLYGON (((122.72165 13.36485, 122.72181 ...
# 5         Central Luzon  MULTIPOLYGON (((120.11687 14.76309, 120.11689 ...
# 14         Davao Region  MULTIPOLYGON (((125.39719 5.43791, 125.39719 5...
# 3         Ilocos Region  MULTIPOLYGON (((119.86596 15.81539, 119.86597 ...
# 10      Western Visayas  MULTIPOLYGON (((122.49684 9.55607, 122.49685 9...
# 11      Central Visayas  MULTIPOLYGON (((123.27039 9.08460, 123.27040 9...
# 16               Caraga  MULTIPOLYGON (((126.34198 8.87710, 126.34167 8...
# 13    Northern Mindanao  MULTIPOLYGON (((123.57503 8.63343, 123.57462 8...
# 8   Zamboanga Peninsula  MULTIPOLYGON (((121.88379 6.69138, 121.88380 6...
# 15         Soccsksargen  MULTIPOLYGON (((124.24158 7.26286, 124.24233 7...
# 7              Mimaropa  MULTIPOLYGON (((117.31260 7.50671, 117.31249 7...
# 12      Eastern Visayas  MULTIPOLYGON (((125.06042 9.96466, 125.06043 9...
# 9          Bicol Region  MULTIPOLYGON (((122.98823 11.73079, 122.98824 ...
# 0                 BARMM  MULTIPOLYGON (((119.46876 4.59360, 119.46881 4...
#
#     covid_cases  population  case_per_pop  percentiles
# 2       1320482    12877253       10254.4  10001-11000
# 1        130358     1797660        7251.5    7001-8000
# 4        175239     3685744        4754.5    4001-5000
# 6        732170    16195042        4521.0    4001-5000
# 5        402291    12422172        3238.5    3001-4000
# 14       156723     5243536        2988.9    2001-3000
# 3        147288     5026128        2930.4    2001-3000
# 10       219393     7536383        2911.1    2001-3000
# 11       210626     8081988        2606.1    2001-3000
# 16        67345     2804788        2401.1    2001-3000
# 13       115136     5022768        2292.3    2001-3000
# 8         71045     3875576        1833.1    1001-2000
# 15        85634     4901486        1747.1    1001-2000
# 7         48312     3228558        1496.4    1001-2000
# 12        67937     4547150        1494.1    1001-2000
# 9         73891     6082165        1214.9    1001-2000
# 0         28543     4404288         648.1       0-1000

# %%
regions_final.dtypes
# Out:
# Shape_Leng       float64
# Shape_Area       float64
# regions           object
# ADM1ALT1EN        object
# geometry        geometry
# covid_cases        int64
# population         int64
# case_per_pop     float64
# percentiles     category
# dtype: object

# %% [markdown]
# **Additional step**: Convert the contents of the percentiles into string. Not doing so will not be read by the GEOJSON file.

# %%
regions_final.percentiles = regions_final.percentiles.astype(str)
regions_final.dtypes
# Out:
# Shape_Leng       float64
# Shape_Area       float64
# regions           object
# ADM1ALT1EN        object
# geometry        geometry
# covid_cases        int64
# population         int64
# case_per_pop     float64
# percentiles       object
# dtype: object

# %% [markdown]
# # Save as GEOJSON file

# %%
regions_final.to_file('regions_cases.geojson', driver='GeoJSON')

# %% [markdown]
# # Simplified file
#
# So we were successful in combining geometry files with our dataset, but the file is too big. We, therefore, use [mapshaper](https://mapshaper.org/) to simplify the precision of the map so that we have a smaller map size.
#
# Below is the simplified json file.

# %%
simplified_regions = gpd.read_file('regions_cases.json')
simplified_regions
# Out:
#     Shape_Leng  Shape_Area                                          regions  \
# 0         53.6         1.1  Bangsamoro Autonomous Region in Muslim Mindanao
# 1          8.0         1.5                 Cordillera Administrative Region
# 2          2.3         0.1                          National Capital Region
# 3         15.0         1.0                                         Region I
# 4         19.1         2.2                                        Region II
# 5         15.9         1.8                                       Region III
# 6         27.6         1.3                                      Region IV-A
# 7         78.8         2.2                                      Region IV-B
# 8         23.2         1.2                                        Region IX
# 9         44.9         1.4                                         Region V
# 10        27.6         1.7                                        Region VI
# 11        29.1         1.2                                       Region VII
# 12        42.0         1.7                                      Region VIII
# 13        15.0         1.4                                         Region X
# 14        17.9         1.5                                        Region XI
# 15        13.2         1.5                                       Region XII
# 16        28.2         1.5                                      Region XIII
#
#              ADM1ALT1EN  covid_cases  population  case_per_pop  percentiles  \
# 0                 BARMM        28543     4404288         648.1       0-1000
# 1                   CAR       130358     1797660        7251.5    7001-8000
# 2                   NCR      1320482    12877253       10254.4  10001-11000
# 3         Ilocos Region       147288     5026128        2930.4    2001-3000
# 4        Cagayan Valley       175239     3685744        4754.5    4001-5000
# 5         Central Luzon       402291    12422172        3238.5    3001-4000
# 6            Calabarzon       732170    16195042        4521.0    4001-5000
# 7              Mimaropa        48312     3228558        1496.4    1001-2000
# 8   Zamboanga Peninsula        71045     3875576        1833.1    1001-2000
# 9          Bicol Region        73891     6082165        1214.9    1001-2000
# 10      Western Visayas       219393     7536383        2911.1    2001-3000
# 11      Central Visayas       210626     8081988        2606.1    2001-3000
# 12      Eastern Visayas        67937     4547150        1494.1    1001-2000
# 13    Northern Mindanao       115136     5022768        2292.3    2001-3000
# 14         Davao Region       156723     5243536        2988.9    2001-3000
# 15         Soccsksargen        85634     4901486        1747.1    1001-2000
# 16               Caraga        67345     2804788        2401.1    2001-3000
#
#                                              geometry
# 0   MULTIPOLYGON (((119.46876 4.59360, 119.46866 4...
# 1   POLYGON ((120.76897 16.19803, 120.77405 16.214...
# 2   POLYGON ((121.09951 14.76921, 121.09939 14.769...
# 3   MULTIPOLYGON (((119.86610 15.81258, 119.86625 ...
# 4   MULTIPOLYGON (((122.46667 16.92135, 122.46654 ...
# 5   MULTIPOLYGON (((120.11687 14.76309, 120.11656 ...
# 6   MULTIPOLYGON (((122.72165 13.36485, 122.72125 ...
# 7   MULTIPOLYGON (((117.31260 7.50671, 117.31306 7...
# 8   MULTIPOLYGON (((121.88379 6.69138, 121.88383 6...
# 9   MULTIPOLYGON (((122.98823 11.73079, 122.98811 ...
# 10  MULTIPOLYGON (((122.49684 9.55607, 122.49670 9...
# 11  MULTIPOLYGON (((123.27039 9.08460, 123.27020 9...
# 12  MULTIPOLYGON (((125.06042 9.96466, 125.06042 9...
# 13  MULTIPOLYGON (((123.57503 8.63343, 123.57485 8...
# 14  MULTIPOLYGON (((125.39719 5.43791, 125.39728 5...
# 15  MULTIPOLYGON (((124.17260 7.19792, 124.17484 7...
# 16  MULTIPOLYGON (((126.34198 8.87710, 126.34221 8...

# %% [markdown]
# ## Convert to GEOJSON

# %%
simplified_regions.to_file('simplified_regions.geojson', driver='GeoJSON')

# %% [markdown]
# ## Fix the CSV file of cases for uploading to site

# %%
simplified_regions = simplified_regions.drop(['Shape_Leng', 'Shape_Area', 'population', 'percentiles', 'geometry'], axis=1)

# %%
simplified_regions
# Out:
#                                             regions           ADM1ALT1EN  \
# 0   Bangsamoro Autonomous Region in Muslim Mindanao                BARMM
# 1                  Cordillera Administrative Region                  CAR
# 2                           National Capital Region                  NCR
# 3                                          Region I        Ilocos Region
# 4                                         Region II       Cagayan Valley
# 5                                        Region III        Central Luzon
# 6                                       Region IV-A           Calabarzon
# 7                                       Region IV-B             Mimaropa
# 8                                         Region IX  Zamboanga Peninsula
# 9                                          Region V         Bicol Region
# 10                                        Region VI      Western Visayas
# 11                                       Region VII      Central Visayas
# 12                                      Region VIII      Eastern Visayas
# 13                                         Region X    Northern Mindanao
# 14                                        Region XI         Davao Region
# 15                                       Region XII         Soccsksargen
# 16                                      Region XIII               Caraga
#
#     covid_cases  case_per_pop
# 0         28543         648.1
# 1        130358        7251.5
# 2       1320482       10254.4
# 3        147288        2930.4
# 4        175239        4754.5
# 5        402291        3238.5
# 6        732170        4521.0
# 7         48312        1496.4
# 8         71045        1833.1
# 9         73891        1214.9
# 10       219393        2911.1
# 11       210626        2606.1
# 12        67937        1494.1
# 13       115136        2292.3
# 14       156723        2988.9
# 15        85634        1747.1
# 16        67345        2401.1

# %%
simplified_regions.columns =['Regions', 'Region name', 'Covid-19 cases', 'Case per 100,000 population']
simplified_regions
# Out:
#                                             Regions          Region name  \
# 0   Bangsamoro Autonomous Region in Muslim Mindanao                BARMM
# 1                  Cordillera Administrative Region                  CAR
# 2                           National Capital Region                  NCR
# 3                                          Region I        Ilocos Region
# 4                                         Region II       Cagayan Valley
# 5                                        Region III        Central Luzon
# 6                                       Region IV-A           Calabarzon
# 7                                       Region IV-B             Mimaropa
# 8                                         Region IX  Zamboanga Peninsula
# 9                                          Region V         Bicol Region
# 10                                        Region VI      Western Visayas
# 11                                       Region VII      Central Visayas
# 12                                      Region VIII      Eastern Visayas
# 13                                         Region X    Northern Mindanao
# 14                                        Region XI         Davao Region
# 15                                       Region XII         Soccsksargen
# 16                                      Region XIII               Caraga
#
#     Covid-19 cases  Case per population
# 0            28543                648.1
# 1           130358               7251.5
# 2          1320482              10254.4
# 3           147288               2930.4
# 4           175239               4754.5
# 5           402291               3238.5
# 6           732170               4521.0
# 7            48312               1496.4
# 8            71045               1833.1
# 9            73891               1214.9
# 10          219393               2911.1
# 11          210626               2606.1
# 12           67937               1494.1
# 13          115136               2292.3
# 14          156723               2988.9
# 15           85634               1747.1
# 16           67345               2401.1

# %%
simplified_regions.to_csv('../data/regions.csv', index=False)
