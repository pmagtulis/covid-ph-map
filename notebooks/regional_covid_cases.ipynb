# %% [markdown]
# # Cleaning Covid data for Mapbox: regions
#
# **Background**: We use Covid-19 cases data in the Philippines from data from the health department and shapefile processed through geopandas to create an interactive map.
#
# **Tools**: pandas, geopandas, Mapbox
#
# Updated: June 18, 2022

# %% [markdown]
# # Do your imports

# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import re
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Read your CSV

# %%
df= pd.read_csv('regions.csv')
df
# Out:
#                         Unnamed: 0  RegionRes
# 0                              NCR    1176864
# 1          Region IV-A: CALABARZON     657098
# 2        Region III: Central Luzon     362611
# 3       Region VI: Western Visayas     195390
# 4      Region VII: Central Visayas     193507
# 5        Region II: Cagayan Valley     162455
# 6          Region XI: Davao Region     140815
# 7          Region I: Ilocos Region     133881
# 8                              CAR     119251
# 9      Region X: Northern Mindanao     106284
# 10        Region XII: SOCCSKSARGEN      76116
# 11  Region IX: Zamboanga Peninsula      66184
# 12          Region V: Bicol Region      65827
# 13    Region VIII: Eastern Visayas      64510
# 14                          CARAGA      62063
# 15           Region IV-B: MIMAROPA      44305
# 16                             ROF      39237
# 17                           BARMM      25895
# 18                             NaN       3359

# %% [markdown]
# ## Lowercase column headers

# %%
df.columns = df.columns.str.lower()
df.head()
# Out:
#                     unnamed: 0  regionres
# 0                          NCR    1176864
# 1      Region IV-A: CALABARZON     657098
# 2    Region III: Central Luzon     362611
# 3   Region VI: Western Visayas     195390
# 4  Region VII: Central Visayas     193507

# %%
df= df.rename(columns={"unnamed: 0": "regions"})
df= df.rename(columns={"regionres": "covid_cases"})
df.head()
# Out:
#                        regions  covid_cases
# 0                          NCR      1176864
# 1      Region IV-A: CALABARZON       657098
# 2    Region III: Central Luzon       362611
# 3   Region VI: Western Visayas       195390
# 4  Region VII: Central Visayas       193507

# %% [markdown]
# # Geopandas
#
# ## Read through file

# %%
region_shape = gpd.read_file('regions.zip')
region_shape
# Out:
#                                             ADM1_EN   ADM1_PCODE     ADM_ID  \
# 0                                        Region VII  PH070000000   70000000
# 1                                         Region VI  PH060000000   60000000
# 2   Bangsamoro Autonomous Region in Muslim Mindanao  PH150000000  150000000
# 3                  Cordillera Administrative Region  PH140000000  140000000
# 4                           National Capital Region  PH130000000  130000000
# 5                                          Region I  PH010000000   10000000
# 6                                         Region II  PH020000000   20000000
# 7                                        Region III  PH030000000   30000000
# 8                                       Region IV-A  PH040000000   40000000
# 9                                       Region IV-B  PH170000000  170000000
# 10                                        Region IX  PH090000000   90000000
# 11                                         Region V  PH050000000   50000000
# 12                                      Region VIII  PH080000000   80000000
# 13                                         Region X  PH100000000  100000000
# 14                                        Region XI  PH110000000  110000000
# 15                                       Region XII  PH120000000  120000000
# 16                                      Region XIII  PH160000000  160000000
#
#        UPDATED    PERIMETER          AREA  LONGITUDE  LATITUDE  \
# 0   2019-12-31  3205930.229  1.429366e+10    123.615     9.921
# 1   2019-12-31  3033678.117  2.004212e+10    122.651    10.844
# 2   2019-12-31  5932722.500  1.283419e+10    123.367     6.947
# 3   2019-12-31   873012.878  1.819264e+10    121.039    17.355
# 4   2019-12-31   253627.782  5.986501e+08    121.032    14.606
# 5   2019-12-31  1632853.395  1.230735e+10    120.484    16.907
# 6   2019-12-31  2071974.767  2.638773e+10    121.732    17.207
# 7   2019-12-31  1739247.236  2.130416e+10    120.823    15.392
# 8   2019-12-31  3019032.066  1.584652e+10    121.567    14.162
# 9   2019-12-31  8661995.346  2.679782e+10    119.906    11.359
# 10  2019-12-31  2560995.195  1.459605e+10    122.848     7.826
# 11  2019-12-31  4917962.098  1.733838e+10    123.472    13.274
# 12  2019-12-31  4616016.122  2.083568e+10    124.953    11.537
# 13  2019-12-31  1657270.815  1.748929e+10    124.674     8.187
# 14  2019-12-31  1982676.485  1.880888e+10    125.827     7.210
# 15  2019-12-31  1463016.962  1.798999e+10    124.813     6.601
# 16  2019-12-31  3104608.438  1.874717e+10    125.791     8.813
#
#                                              geometry
# 0   MULTIPOLYGON (((123.11764 9.64950, 123.11765 9...
# 1   MULTIPOLYGON (((122.36748 9.83003, 122.36750 9...
# 2   MULTIPOLYGON (((119.46876 4.59360, 119.46881 4...
# 3   POLYGON ((121.22208 18.50058, 121.22086 18.483...
# 4   POLYGON ((121.03842 14.78525, 121.03876 14.785...
# 5   MULTIPOLYGON (((119.86596 15.81539, 119.86597 ...
# 6   MULTIPOLYGON (((122.46667 16.92135, 122.46674 ...
# 7   MULTIPOLYGON (((120.11687 14.76309, 120.11689 ...
# 8   MULTIPOLYGON (((122.72165 13.36485, 122.72181 ...
# 9   MULTIPOLYGON (((117.31260 7.50671, 117.31249 7...
# 10  MULTIPOLYGON (((121.88379 6.69138, 121.88380 6...
# 11  MULTIPOLYGON (((122.98823 11.73079, 122.98824 ...
# 12  MULTIPOLYGON (((125.06042 9.96466, 125.06043 9...
# 13  MULTIPOLYGON (((123.64583 8.01284, 123.64455 8...
# 14  MULTIPOLYGON (((125.39719 5.43791, 125.39719 5...
# 15  MULTIPOLYGON (((124.03302 6.74128, 124.03300 6...
# 16  MULTIPOLYGON (((126.34198 8.87710, 126.34167 8...

# %% [markdown]
# ## Clean regional names in the dataset
#
# This is so they would match the names in the shapefile for merging later.

# %%
df.regions = df.regions.str.replace("NCR", "National Capital Region", regex=False)
df.regions = df.regions.str.replace("BARMM", "Bangsamoro Autonomous Region in Muslim Mindanao", regex=False)
df.regions = df.regions.str.replace("CAR", "Cordillera Administrative Region", regex=False)
df.regions = df.regions.str.replace("Cordillera Administrative RegionAGA", "Region XIII", regex=False)
df.regions = df.regions.str.replace(r'[:].*$', "", regex=True)
df.regions
# Out:
# 0                             National Capital Region
# 1                                         Region IV-A
# 2                                          Region III
# 3                                           Region VI
# 4                                          Region VII
# 5                                           Region II
# 6                                           Region XI
# 7                                            Region I
# 8                    Cordillera Administrative Region
# 9                                            Region X
# 10                                         Region XII
# 11                                          Region IX
# 12                                           Region V
# 13                                        Region VIII
# 14                                        Region XIII
# 15                                        Region IV-B
# 16                                                ROF
# 17    Bangsamoro Autonomous Region in Muslim Mindanao
# 18                                                NaN
# Name: regions, dtype: object

# %% [markdown]
# ## Clean the shapefile data
#
# ### Lowercase headers

# %%
region_shape.columns = region_shape.columns.str.lower()

# %% [markdown]
# ### Drop unnecessary columns from shapefile

# %%
region_shape = region_shape.drop(['updated', 'adm_id','adm1_pcode', 'area', 'perimeter', 'latitude', 'longitude'], axis=1)
region_shape
# Out:
#                                             adm1_en  \
# 0                                        Region VII
# 1                                         Region VI
# 2   Bangsamoro Autonomous Region in Muslim Mindanao
# 3                  Cordillera Administrative Region
# 4                           National Capital Region
# 5                                          Region I
# 6                                         Region II
# 7                                        Region III
# 8                                       Region IV-A
# 9                                       Region IV-B
# 10                                        Region IX
# 11                                         Region V
# 12                                      Region VIII
# 13                                         Region X
# 14                                        Region XI
# 15                                       Region XII
# 16                                      Region XIII
#
#                                              geometry
# 0   MULTIPOLYGON (((123.11764 9.64950, 123.11765 9...
# 1   MULTIPOLYGON (((122.36748 9.83003, 122.36750 9...
# 2   MULTIPOLYGON (((119.46876 4.59360, 119.46881 4...
# 3   POLYGON ((121.22208 18.50058, 121.22086 18.483...
# 4   POLYGON ((121.03842 14.78525, 121.03876 14.785...
# 5   MULTIPOLYGON (((119.86596 15.81539, 119.86597 ...
# 6   MULTIPOLYGON (((122.46667 16.92135, 122.46674 ...
# 7   MULTIPOLYGON (((120.11687 14.76309, 120.11689 ...
# 8   MULTIPOLYGON (((122.72165 13.36485, 122.72181 ...
# 9   MULTIPOLYGON (((117.31260 7.50671, 117.31249 7...
# 10  MULTIPOLYGON (((121.88379 6.69138, 121.88380 6...
# 11  MULTIPOLYGON (((122.98823 11.73079, 122.98824 ...
# 12  MULTIPOLYGON (((125.06042 9.96466, 125.06043 9...
# 13  MULTIPOLYGON (((123.64583 8.01284, 123.64455 8...
# 14  MULTIPOLYGON (((125.39719 5.43791, 125.39719 5...
# 15  MULTIPOLYGON (((124.03302 6.74128, 124.03300 6...
# 16  MULTIPOLYGON (((126.34198 8.87710, 126.34167 8...

# %%
region_shape= region_shape.rename(columns={"adm1_en": "regions"})

# %% [markdown]
# ## Merge data

# %%
regions_cases = region_shape.merge(df, on='regions')
regions_cases.head()
# Out:
#                                            regions  \
# 0                                       Region VII
# 1                                        Region VI
# 2  Bangsamoro Autonomous Region in Muslim Mindanao
# 3                 Cordillera Administrative Region
# 4                          National Capital Region
#
#                                             geometry  covid_cases
# 0  MULTIPOLYGON (((123.11764 9.64950, 123.11765 9...       193507
# 1  MULTIPOLYGON (((122.36748 9.83003, 122.36750 9...       195390
# 2  MULTIPOLYGON (((119.46876 4.59360, 119.46881 4...        25895
# 3  POLYGON ((121.22208 18.50058, 121.22086 18.483...       119251
# 4  POLYGON ((121.03842 14.78525, 121.03876 14.785...      1176864

# %% [markdown]
# ## Read and merge with population data

# %%
df2 = pd.read_excel('population.xlsx')
df2.head()
# Out:
#                             regions  population
# 0           National Capital Region    12877253
# 1  Cordillera Administrative Region     1797660
# 2                          Region I     5026128
# 3                         Region II     3685744
# 4                        Region III    12422172

# %%
regions_final = regions_cases.merge(df2, on='regions')
regions_final.head()
# Out:
#                                            regions  \
# 0                                       Region VII
# 1                                        Region VI
# 2  Bangsamoro Autonomous Region in Muslim Mindanao
# 3                 Cordillera Administrative Region
# 4                          National Capital Region
#
#                                             geometry  covid_cases  population
# 0  MULTIPOLYGON (((123.11764 9.64950, 123.11765 9...       193507     8081988
# 1  MULTIPOLYGON (((122.36748 9.83003, 122.36750 9...       195390     7536383
# 2  MULTIPOLYGON (((119.46876 4.59360, 119.46881 4...        25895     4404288
# 3  POLYGON ((121.22208 18.50058, 121.22086 18.483...       119251     1797660
# 4  POLYGON ((121.03842 14.78525, 121.03876 14.785...      1176864    12877253

# %% [markdown]
# ## Compute for population ratio
#
# We do this by dividing the number of Covid-19 cases to total population per region and then multiply by 100,000. That would give us cases per 100,000 people in the area.

# %%
regions_final ['case_per_pop'] = regions_final.covid_cases / regions_final.population * 100000
regions_final = regions_final.round(1)

# %% [markdown]
# ## Create bins for cases
#
# The bins will allow us to categorize the number of cases, necessary for mapping later.

# %%
regions_final['percentiles'] = pd.cut(np.array(regions_final['case_per_pop']),
   [0, 1001, 2001, 3001, 4001, 5001, 6001, 7001, 8001, 9001, 10000], labels=["0-1000", "1001-2000", "2001-3000", "3001-4000", "4001-5000", "5001-6000", "6001-7000", "7001-8000", "8001-9000", "9001-10000"])

regions_final.head()
# Out:
#                                            regions  \
# 0                                       Region VII
# 1                                        Region VI
# 2  Bangsamoro Autonomous Region in Muslim Mindanao
# 3                 Cordillera Administrative Region
# 4                          National Capital Region
#
#                                             geometry  covid_cases  population  \
# 0  MULTIPOLYGON (((123.11764 9.64950, 123.11765 9...       193507     8081988
# 1  MULTIPOLYGON (((122.36748 9.83003, 122.36750 9...       195390     7536383
# 2  MULTIPOLYGON (((119.46876 4.59360, 119.46881 4...        25895     4404288
# 3  POLYGON ((121.22208 18.50058, 121.22086 18.483...       119251     1797660
# 4  POLYGON ((121.03842 14.78525, 121.03876 14.785...      1176864    12877253
#
#    case_per_pop percentiles
# 0        2394.3   2001-3000
# 1        2592.6   2001-3000
# 2         587.9      0-1000
# 3        6633.7   6001-7000
# 4        9139.1  9001-10000

# %%
regions_final.dtypes
# Out:
# regions           object
# geometry        geometry
# covid_cases        int64
# population         int64
# case_per_pop     float64
# percentiles     category
# dtype: object

# %% [markdown]
# **Additional step**: Convert the contents of the percentiles into string. Not doing so will not be read by the GEOJSON file.

# %%
regions_final.percentiles = regions_final.percentiles.astype(str)
regions_final.dtypes
# Out:
# regions           object
# geometry        geometry
# covid_cases        int64
# population         int64
# case_per_pop     float64
# percentiles       object
# dtype: object

# %% [markdown]
# # Save as GEOJSON file

# %%
regions_final.to_file('regions_cases.geojson', driver='GeoJSON')
# Out:
# /Users/prinzmagtulis/.pyenv/versions/3.10.0/lib/python3.10/site-packages/geopandas/io/file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,

# %% [markdown]
# # Simplified file
#
# So we were successful in combining geometry files with our dataset, but the file is too big. We, therefore, use [mapshaper](https://mapshaper.org/) to simplify the precision of the map so that we have a smaller map size.
#
# Below is the simplified json file.

# %%
simplified_regions = gpd.read_file('regions_cases.json')
simplified_regions
# Out:
#                                             regions  covid_cases  population  \
# 0                                        Region VII       193507     8081988
# 1                                         Region VI       195390     7536383
# 2   Bangsamoro Autonomous Region in Muslim Mindanao        25895     4404288
# 3                  Cordillera Administrative Region       119251     1797660
# 4                           National Capital Region      1176864    12877253
# 5                                          Region I       133881     5026128
# 6                                         Region II       162455     3685744
# 7                                        Region III       362611    12422172
# 8                                       Region IV-A       657098    16195042
# 9                                       Region IV-B        44305     3228558
# 10                                        Region IX        66184     3875576
# 11                                         Region V        65827     6082165
# 12                                      Region VIII        64510     4547150
# 13                                         Region X       106284     5022768
# 14                                        Region XI       140815     5243536
# 15                                       Region XII        76116     4901486
# 16                                      Region XIII        62063     2804788
#
#     case_per_pop percentiles  \
# 0         2394.3   2001-3000
# 1         2592.6   2001-3000
# 2          587.9      0-1000
# 3         6633.7   6001-7000
# 4         9139.1  9001-10000
# 5         2663.7   2001-3000
# 6         4407.7   4001-5000
# 7         2919.1   2001-3000
# 8         4057.4   4001-5000
# 9         1372.3   1001-2000
# 10        1707.7   1001-2000
# 11        1082.3   1001-2000
# 12        1418.7   1001-2000
# 13        2116.0   2001-3000
# 14        2685.5   2001-3000
# 15        1552.9   1001-2000
# 16        2212.8   2001-3000
#
#                                              geometry
# 0   MULTIPOLYGON (((123.27039 9.08460, 123.26843 9...
# 1   MULTIPOLYGON (((122.36748 9.83003, 122.36521 9...
# 2   MULTIPOLYGON (((119.46876 4.59360, 119.46798 4...
# 3   POLYGON ((120.76897 16.19803, 120.77448 16.216...
# 4   POLYGON ((121.09951 14.76921, 121.09936 14.771...
# 5   MULTIPOLYGON (((119.86610 15.81258, 119.86682 ...
# 6   MULTIPOLYGON (((122.46667 16.92135, 122.46723 ...
# 7   MULTIPOLYGON (((120.11687 14.76309, 120.11450 ...
# 8   MULTIPOLYGON (((122.72165 13.36485, 122.71908 ...
# 9   MULTIPOLYGON (((117.31260 7.50671, 117.31386 7...
# 10  MULTIPOLYGON (((121.88379 6.69138, 121.88254 6...
# 11  MULTIPOLYGON (((123.02405 11.75896, 123.02256 ...
# 12  MULTIPOLYGON (((125.06042 9.96466, 125.05962 9...
# 13  MULTIPOLYGON (((123.57503 8.63343, 123.57287 8...
# 14  MULTIPOLYGON (((125.39719 5.43791, 125.39681 5...
# 15  MULTIPOLYGON (((124.17260 7.19792, 124.17775 7...
# 16  MULTIPOLYGON (((126.34198 8.87710, 126.34176 8...

# %% [markdown]
# ## Convert to GEOJSON

# %%
simplified_regions.to_file('simplified_regions.geojson', driver='GeoJSON')
# Out:
# /Users/prinzmagtulis/.pyenv/versions/3.10.0/lib/python3.10/site-packages/geopandas/io/file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,

# %%
simplified_regions
# Out:
#                                             regions  covid_cases  population  \
# 0                                        Region VII       193507     8081988
# 1                                         Region VI       195390     7536383
# 2   Bangsamoro Autonomous Region in Muslim Mindanao        25895     4404288
# 3                  Cordillera Administrative Region       119251     1797660
# 4                           National Capital Region      1176864    12877253
# 5                                          Region I       133881     5026128
# 6                                         Region II       162455     3685744
# 7                                        Region III       362611    12422172
# 8                                       Region IV-A       657098    16195042
# 9                                       Region IV-B        44305     3228558
# 10                                        Region IX        66184     3875576
# 11                                         Region V        65827     6082165
# 12                                      Region VIII        64510     4547150
# 13                                         Region X       106284     5022768
# 14                                        Region XI       140815     5243536
# 15                                       Region XII        76116     4901486
# 16                                      Region XIII        62063     2804788
#
#     case_per_pop percentiles  \
# 0         2394.3   2001-3000
# 1         2592.6   2001-3000
# 2          587.9      0-1000
# 3         6633.7   6001-7000
# 4         9139.1  9001-10000
# 5         2663.7   2001-3000
# 6         4407.7   4001-5000
# 7         2919.1   2001-3000
# 8         4057.4   4001-5000
# 9         1372.3   1001-2000
# 10        1707.7   1001-2000
# 11        1082.3   1001-2000
# 12        1418.7   1001-2000
# 13        2116.0   2001-3000
# 14        2685.5   2001-3000
# 15        1552.9   1001-2000
# 16        2212.8   2001-3000
#
#                                              geometry
# 0   MULTIPOLYGON (((123.27039 9.08460, 123.26843 9...
# 1   MULTIPOLYGON (((122.36748 9.83003, 122.36521 9...
# 2   MULTIPOLYGON (((119.46876 4.59360, 119.46798 4...
# 3   POLYGON ((120.76897 16.19803, 120.77448 16.216...
# 4   POLYGON ((121.09951 14.76921, 121.09936 14.771...
# 5   MULTIPOLYGON (((119.86610 15.81258, 119.86682 ...
# 6   MULTIPOLYGON (((122.46667 16.92135, 122.46723 ...
# 7   MULTIPOLYGON (((120.11687 14.76309, 120.11450 ...
# 8   MULTIPOLYGON (((122.72165 13.36485, 122.71908 ...
# 9   MULTIPOLYGON (((117.31260 7.50671, 117.31386 7...
# 10  MULTIPOLYGON (((121.88379 6.69138, 121.88254 6...
# 11  MULTIPOLYGON (((123.02405 11.75896, 123.02256 ...
# 12  MULTIPOLYGON (((125.06042 9.96466, 125.05962 9...
# 13  MULTIPOLYGON (((123.57503 8.63343, 123.57287 8...
# 14  MULTIPOLYGON (((125.39719 5.43791, 125.39681 5...
# 15  MULTIPOLYGON (((124.17260 7.19792, 124.17775 7...
# 16  MULTIPOLYGON (((126.34198 8.87710, 126.34176 8...
