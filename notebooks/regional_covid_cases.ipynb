# %% [markdown]
# # Cleaning Covid data for Mapbox: regions
#
# **Background**: We use Covid-19 cases data in the Philippines from data from the health department and shapefile processed through geopandas to create an interactive map.
#
# **Tools**: pandas, geopandas, Mapbox

# %% [markdown]
# # Do your imports

# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import re
from shapely.geometry import Point, LineString
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Read your CSV

# %%
df= pd.read_csv('regions.csv')
df
# Out:
#                         Unnamed: 0  RegionRes
# 0                              NCR    1174255
# 1          Region IV-A: CALABARZON     656289
# 2        Region III: Central Luzon     362209
# 3       Region VI: Western Visayas     194989
# 4      Region VII: Central Visayas     193299
# 5        Region II: Cagayan Valley     162378
# 6          Region XI: Davao Region     140681
# 7          Region I: Ilocos Region     133758
# 8                              CAR     119192
# 9      Region X: Northern Mindanao     106189
# 10        Region XII: SOCCSKSARGEN      75975
# 11  Region IX: Zamboanga Peninsula      66097
# 12          Region V: Bicol Region      65786
# 13    Region VIII: Eastern Visayas      64444
# 14                          CARAGA      62003
# 15           Region IV-B: MIMAROPA      44238
# 16                             ROF      39237
# 17                           BARMM      25876
# 18                             NaN       3359

# %% [markdown]
# ## Lowercase column headers

# %%
df.columns = df.columns.str.lower()
df
# Out:
#                         unnamed: 0  regionres
# 0                              NCR    1174255
# 1          Region IV-A: CALABARZON     656289
# 2        Region III: Central Luzon     362209
# 3       Region VI: Western Visayas     194989
# 4      Region VII: Central Visayas     193299
# 5        Region II: Cagayan Valley     162378
# 6          Region XI: Davao Region     140681
# 7          Region I: Ilocos Region     133758
# 8                              CAR     119192
# 9      Region X: Northern Mindanao     106189
# 10        Region XII: SOCCSKSARGEN      75975
# 11  Region IX: Zamboanga Peninsula      66097
# 12          Region V: Bicol Region      65786
# 13    Region VIII: Eastern Visayas      64444
# 14                          CARAGA      62003
# 15           Region IV-B: MIMAROPA      44238
# 16                             ROF      39237
# 17                           BARMM      25876
# 18                             NaN       3359

# %%
df= df.rename(columns={"unnamed: 0": "regions"})
df= df.rename(columns={"regionres": "covid_cases"})
df.head()
# Out:
#                            regions  covid_cases
# 0                              NCR      1174255
# 1          Region IV-A: CALABARZON       656289
# 2        Region III: Central Luzon       362209
# 3       Region VI: Western Visayas       194989
# 4      Region VII: Central Visayas       193299
# 5        Region II: Cagayan Valley       162378
# 6          Region XI: Davao Region       140681
# 7          Region I: Ilocos Region       133758
# 8                              CAR       119192
# 9      Region X: Northern Mindanao       106189
# 10        Region XII: SOCCSKSARGEN        75975
# 11  Region IX: Zamboanga Peninsula        66097
# 12          Region V: Bicol Region        65786
# 13    Region VIII: Eastern Visayas        64444
# 14                          CARAGA        62003
# 15           Region IV-B: MIMAROPA        44238
# 16                             ROF        39237
# 17                           BARMM        25876
# 18                             NaN         3359

# %% [markdown]
# # Geopandas
#
# ## Read through file

# %%
region_shape = gpd.read_file('regions-ph.zip')
region_shape.head()
# Out:
#     Shape_Leng  Shape_Area                               ADM1_EN   ADM1_PCODE  \
# 0    53.623497    1.050272  Autonomous Region in Muslim Mindanao  PH150000000
# 1     8.027454    1.546712      Cordillera Administrative Region  PH140000000
# 2     2.320234    0.050216               National Capital Region  PH130000000
# 3    14.995101    1.043983                              Region I  PH010000000
# 4    19.139048    2.241812                             Region II  PH020000000
# 5    15.949563    1.793513                            Region III  PH030000000
# 6    27.624115    1.326710                           Region IV-A  PH040000000
# 7    78.804542    2.220374                           Region IV-B  PH170000000
# 8    23.181441    1.196677                             Region IX  PH090000000
# 9    44.923243    1.446324                              Region V  PH050000000
# 10   27.589382    1.657135                             Region VI  PH060000000
# 11   29.113105    1.178431                            Region VII  PH070000000
# 12   42.021179    1.726804                           Region VIII  PH080000000
# 13   15.002953    1.435115                              Region X  PH100000000
# 14   17.934222    1.539971                             Region XI  PH110000000
# 15   13.229749    1.471068                            Region XII  PH120000000
# 16   28.166754    1.540820                           Region XIII  PH160000000
#
#    ADM1_REF           ADM1ALT1EN ADM1ALT2EN            ADM0_EN ADM0_PCODE  \
# 0      None                 ARMM       None  Philippines (the)         PH
# 1      None                  CAR       None  Philippines (the)         PH
# 2      None                  NCR       None  Philippines (the)         PH
# 3      None        Ilocos Region       None  Philippines (the)         PH
# 4      None       Cagayan Valley       None  Philippines (the)         PH
# 5      None        Central Luzon       None  Philippines (the)         PH
# 6      None           Calabarzon       None  Philippines (the)         PH
# 7      None             Mimaropa       None  Philippines (the)         PH
# 8      None  Zamboanga Peninsula       None  Philippines (the)         PH
# 9      None         Bicol Region       None  Philippines (the)         PH
# 10     None      Western Visayas       None  Philippines (the)         PH
# 11     None      Central Visayas       None  Philippines (the)         PH
# 12     None      Eastern Visayas       None  Philippines (the)         PH
# 13     None    Northern Mindanao       None  Philippines (the)         PH
# 14     None         Davao Region       None  Philippines (the)         PH
# 15     None         Soccsksargen       None  Philippines (the)         PH
# 16     None               Caraga       None  Philippines (the)         PH
#
#           date     validOn validTo  \
# 0   2016-06-30  2020-05-29    None
# 1   2016-06-30  2020-05-29    None
# 2   2016-06-30  2020-05-29    None
# 3   2016-06-30  2020-05-29    None
# 4   2016-06-30  2020-05-29    None
# 5   2016-06-30  2020-05-29    None
# 6   2016-06-30  2020-05-29    None
# 7   2016-06-30  2020-05-29    None
# 8   2016-06-30  2020-05-29    None
# 9   2016-06-30  2020-05-29    None
# 10  2016-06-30  2020-05-29    None
# 11  2016-06-30  2020-05-29    None
# 12  2016-06-30  2020-05-29    None
# 13  2016-06-30  2020-05-29    None
# 14  2016-06-30  2020-05-29    None
# 15  2016-06-30  2020-05-29    None
# 16  2016-06-30  2020-05-29    None
#
#                                              geometry
# 0   MULTIPOLYGON (((119.46876 4.59360, 119.46881 4...
# 1   POLYGON ((121.22208 18.50058, 121.22086 18.483...
# 2   POLYGON ((121.03842 14.78525, 121.03876 14.785...
# 3   MULTIPOLYGON (((119.86596 15.81539, 119.86597 ...
# 4   MULTIPOLYGON (((122.46667 16.92135, 122.46674 ...
# 5   MULTIPOLYGON (((120.11687 14.76309, 120.11689 ...
# 6   MULTIPOLYGON (((122.72165 13.36485, 122.72181 ...
# 7   MULTIPOLYGON (((117.31260 7.50671, 117.31249 7...
# 8   MULTIPOLYGON (((121.88379 6.69138, 121.88380 6...
# 9   MULTIPOLYGON (((122.98823 11.73079, 122.98824 ...
# 10  MULTIPOLYGON (((122.49684 9.55607, 122.49685 9...
# 11  MULTIPOLYGON (((123.27039 9.08460, 123.27040 9...
# 12  MULTIPOLYGON (((125.06042 9.96466, 125.06043 9...
# 13  MULTIPOLYGON (((123.57503 8.63343, 123.57462 8...
# 14  MULTIPOLYGON (((125.39719 5.43791, 125.39719 5...
# 15  MULTIPOLYGON (((124.24158 7.26286, 124.24233 7...
# 16  MULTIPOLYGON (((126.34198 8.87710, 126.34167 8...

# %% [markdown]
# ## Clean regional names in the dataset
#
# This is so they would match the names in the shapefile for merging later.

# %%
df.regions = df.regions.str.replace("NCR", "National Capital Region", regex=False)
df.regions = df.regions.str.replace("BARMM", "Autonomous Region in Muslim Mindanao", regex=False)
df.regions = df.regions.str.replace("CAR", "Cordillera Administrative Region", regex=False)
df.regions = df.regions.str.replace("CARAGA", "Region XIII", regex=False)
df.regions = df.regions.str.replace(r'[:].*$', "", regex=True)
df.regions
# Out:
# 0                  National Capital Region
# 1                              Region IV-A
# 2                               Region III
# 3                                Region VI
# 4                               Region VII
# 5                                Region II
# 6                                Region XI
# 7                                 Region I
# 8         Cordillera Administrative Region
# 9                                 Region X
# 10                              Region XII
# 11                               Region IX
# 12                                Region V
# 13                             Region VIII
# 14     Cordillera Administrative RegionAGA
# 15                             Region IV-B
# 16                                     ROF
# 17    Autonomous Region in Muslim Mindanao
# 18                                     NaN
# Name: regions, dtype: object

# %% [markdown]
# ## Clean the shapefile data
#
# ### Lowercase headers

# %%
region_shape.columns = region_shape.columns.str.lower()
# Out:
#     shape_leng  shape_area                               adm1_en   adm1_pcode  \
# 0    53.623497    1.050272  Autonomous Region in Muslim Mindanao  PH150000000
# 1     8.027454    1.546712      Cordillera Administrative Region  PH140000000
# 2     2.320234    0.050216               National Capital Region  PH130000000
# 3    14.995101    1.043983                              Region I  PH010000000
# 4    19.139048    2.241812                             Region II  PH020000000
# 5    15.949563    1.793513                            Region III  PH030000000
# 6    27.624115    1.326710                           Region IV-A  PH040000000
# 7    78.804542    2.220374                           Region IV-B  PH170000000
# 8    23.181441    1.196677                             Region IX  PH090000000
# 9    44.923243    1.446324                              Region V  PH050000000
# 10   27.589382    1.657135                             Region VI  PH060000000
# 11   29.113105    1.178431                            Region VII  PH070000000
# 12   42.021179    1.726804                           Region VIII  PH080000000
# 13   15.002953    1.435115                              Region X  PH100000000
# 14   17.934222    1.539971                             Region XI  PH110000000
# 15   13.229749    1.471068                            Region XII  PH120000000
# 16   28.166754    1.540820                           Region XIII  PH160000000
#
#    adm1_ref           adm1alt1en adm1alt2en            adm0_en adm0_pcode  \
# 0      None                 ARMM       None  Philippines (the)         PH
# 1      None                  CAR       None  Philippines (the)         PH
# 2      None                  NCR       None  Philippines (the)         PH
# 3      None        Ilocos Region       None  Philippines (the)         PH
# 4      None       Cagayan Valley       None  Philippines (the)         PH
# 5      None        Central Luzon       None  Philippines (the)         PH
# 6      None           Calabarzon       None  Philippines (the)         PH
# 7      None             Mimaropa       None  Philippines (the)         PH
# 8      None  Zamboanga Peninsula       None  Philippines (the)         PH
# 9      None         Bicol Region       None  Philippines (the)         PH
# 10     None      Western Visayas       None  Philippines (the)         PH
# 11     None      Central Visayas       None  Philippines (the)         PH
# 12     None      Eastern Visayas       None  Philippines (the)         PH
# 13     None    Northern Mindanao       None  Philippines (the)         PH
# 14     None         Davao Region       None  Philippines (the)         PH
# 15     None         Soccsksargen       None  Philippines (the)         PH
# 16     None               Caraga       None  Philippines (the)         PH
#
#           date     validon validto  \
# 0   2016-06-30  2020-05-29    None
# 1   2016-06-30  2020-05-29    None
# 2   2016-06-30  2020-05-29    None
# 3   2016-06-30  2020-05-29    None
# 4   2016-06-30  2020-05-29    None
# 5   2016-06-30  2020-05-29    None
# 6   2016-06-30  2020-05-29    None
# 7   2016-06-30  2020-05-29    None
# 8   2016-06-30  2020-05-29    None
# 9   2016-06-30  2020-05-29    None
# 10  2016-06-30  2020-05-29    None
# 11  2016-06-30  2020-05-29    None
# 12  2016-06-30  2020-05-29    None
# 13  2016-06-30  2020-05-29    None
# 14  2016-06-30  2020-05-29    None
# 15  2016-06-30  2020-05-29    None
# 16  2016-06-30  2020-05-29    None
#
#                                              geometry
# 0   MULTIPOLYGON (((119.46876 4.59360, 119.46881 4...
# 1   POLYGON ((121.22208 18.50058, 121.22086 18.483...
# 2   POLYGON ((121.03842 14.78525, 121.03876 14.785...
# 3   MULTIPOLYGON (((119.86596 15.81539, 119.86597 ...
# 4   MULTIPOLYGON (((122.46667 16.92135, 122.46674 ...
# 5   MULTIPOLYGON (((120.11687 14.76309, 120.11689 ...
# 6   MULTIPOLYGON (((122.72165 13.36485, 122.72181 ...
# 7   MULTIPOLYGON (((117.31260 7.50671, 117.31249 7...
# 8   MULTIPOLYGON (((121.88379 6.69138, 121.88380 6...
# 9   MULTIPOLYGON (((122.98823 11.73079, 122.98824 ...
# 10  MULTIPOLYGON (((122.49684 9.55607, 122.49685 9...
# 11  MULTIPOLYGON (((123.27039 9.08460, 123.27040 9...
# 12  MULTIPOLYGON (((125.06042 9.96466, 125.06043 9...
# 13  MULTIPOLYGON (((123.57503 8.63343, 123.57462 8...
# 14  MULTIPOLYGON (((125.39719 5.43791, 125.39719 5...
# 15  MULTIPOLYGON (((124.24158 7.26286, 124.24233 7...
# 16  MULTIPOLYGON (((126.34198 8.87710, 126.34167 8...

# %% [markdown]
# ### Drop unnecessary columns from shapefile

# %%
region_shape = region_shape.drop(['adm1_pcode', 'adm1_ref','adm1alt1en', 'adm1alt2en', 'adm0_en', 'shape_leng', 'shape_area', 'adm0_pcode', 'date', 'validon', 'validto'], axis=1)
region_shape
# Out:
#                                  adm1_en  \
# 0   Autonomous Region in Muslim Mindanao
# 1       Cordillera Administrative Region
# 2                National Capital Region
# 3                               Region I
# 4                              Region II
# 5                             Region III
# 6                            Region IV-A
# 7                            Region IV-B
# 8                              Region IX
# 9                               Region V
# 10                             Region VI
# 11                            Region VII
# 12                           Region VIII
# 13                              Region X
# 14                             Region XI
# 15                            Region XII
# 16                           Region XIII
#
#                                              geometry
# 0   MULTIPOLYGON (((119.46876 4.59360, 119.46881 4...
# 1   POLYGON ((121.22208 18.50058, 121.22086 18.483...
# 2   POLYGON ((121.03842 14.78525, 121.03876 14.785...
# 3   MULTIPOLYGON (((119.86596 15.81539, 119.86597 ...
# 4   MULTIPOLYGON (((122.46667 16.92135, 122.46674 ...
# 5   MULTIPOLYGON (((120.11687 14.76309, 120.11689 ...
# 6   MULTIPOLYGON (((122.72165 13.36485, 122.72181 ...
# 7   MULTIPOLYGON (((117.31260 7.50671, 117.31249 7...
# 8   MULTIPOLYGON (((121.88379 6.69138, 121.88380 6...
# 9   MULTIPOLYGON (((122.98823 11.73079, 122.98824 ...
# 10  MULTIPOLYGON (((122.49684 9.55607, 122.49685 9...
# 11  MULTIPOLYGON (((123.27039 9.08460, 123.27040 9...
# 12  MULTIPOLYGON (((125.06042 9.96466, 125.06043 9...
# 13  MULTIPOLYGON (((123.57503 8.63343, 123.57462 8...
# 14  MULTIPOLYGON (((125.39719 5.43791, 125.39719 5...
# 15  MULTIPOLYGON (((124.24158 7.26286, 124.24233 7...
# 16  MULTIPOLYGON (((126.34198 8.87710, 126.34167 8...

# %%
region_shape= region_shape.rename(columns={"adm1_en": "regions"})

# %% [markdown]
# ## Merge data

# %%
regions_cases = region_shape.merge(df, on='regions')
regions_cases
# Out:
#                                  regions  \
# 0   Autonomous Region in Muslim Mindanao
# 1       Cordillera Administrative Region
# 2                National Capital Region
# 3                               Region I
# 4                              Region II
# 5                             Region III
# 6                            Region IV-A
# 7                            Region IV-B
# 8                              Region IX
# 9                               Region V
# 10                             Region VI
# 11                            Region VII
# 12                           Region VIII
# 13                              Region X
# 14                             Region XI
# 15                            Region XII
#
#                                              geometry  covid_cases
# 0   MULTIPOLYGON (((119.46876 4.59360, 119.46881 4...        25876
# 1   POLYGON ((121.22208 18.50058, 121.22086 18.483...       119192
# 2   POLYGON ((121.03842 14.78525, 121.03876 14.785...      1174255
# 3   MULTIPOLYGON (((119.86596 15.81539, 119.86597 ...       133758
# 4   MULTIPOLYGON (((122.46667 16.92135, 122.46674 ...       162378
# 5   MULTIPOLYGON (((120.11687 14.76309, 120.11689 ...       362209
# 6   MULTIPOLYGON (((122.72165 13.36485, 122.72181 ...       656289
# 7   MULTIPOLYGON (((117.31260 7.50671, 117.31249 7...        44238
# 8   MULTIPOLYGON (((121.88379 6.69138, 121.88380 6...        66097
# 9   MULTIPOLYGON (((122.98823 11.73079, 122.98824 ...        65786
# 10  MULTIPOLYGON (((122.49684 9.55607, 122.49685 9...       194989
# 11  MULTIPOLYGON (((123.27039 9.08460, 123.27040 9...       193299
# 12  MULTIPOLYGON (((125.06042 9.96466, 125.06043 9...        64444
# 13  MULTIPOLYGON (((123.57503 8.63343, 123.57462 8...       106189
# 14  MULTIPOLYGON (((125.39719 5.43791, 125.39719 5...       140681
# 15  MULTIPOLYGON (((124.24158 7.26286, 124.24233 7...        75975

# %%
regions_cases.covid_cases.sort_values(ascending=False)
# Out:
# 2     1174255
# 6      656289
# 5      362209
# 10     194989
# 11     193299
# 4      162378
# 14     140681
# 3      133758
# 1      119192
# 13     106189
# 15      75975
# 8       66097
# 9       65786
# 12      64444
# 7       44238
# 0       25876
# Name: covid_cases, dtype: int64

# %% [markdown]
# ## Create bins for cases
#
# The bins will allow us to categorize the number of cases, necessary for mapping later.

# %%
regions_cases['percentiles'] = pd.cut(np.array(regions_cases['covid_cases']),
   10, labels=["0-100000", "100000-200000", "200000-300000", "300000-400000", "400000-500000", "500000-600000", "600000-700000", "700000-800000", "800000-900000", "900000-1200000"])

regions_cases
# Out:
#                                  regions  \
# 0   Autonomous Region in Muslim Mindanao
# 1       Cordillera Administrative Region
# 2                National Capital Region
# 3                               Region I
# 4                              Region II
# 5                             Region III
# 6                            Region IV-A
# 7                            Region IV-B
# 8                              Region IX
# 9                               Region V
# 10                             Region VI
# 11                            Region VII
# 12                           Region VIII
# 13                              Region X
# 14                             Region XI
# 15                            Region XII
#
#                                              geometry  covid_cases  \
# 0   MULTIPOLYGON (((119.46876 4.59360, 119.46881 4...        25876
# 1   POLYGON ((121.22208 18.50058, 121.22086 18.483...       119192
# 2   POLYGON ((121.03842 14.78525, 121.03876 14.785...      1174255
# 3   MULTIPOLYGON (((119.86596 15.81539, 119.86597 ...       133758
# 4   MULTIPOLYGON (((122.46667 16.92135, 122.46674 ...       162378
# 5   MULTIPOLYGON (((120.11687 14.76309, 120.11689 ...       362209
# 6   MULTIPOLYGON (((122.72165 13.36485, 122.72181 ...       656289
# 7   MULTIPOLYGON (((117.31260 7.50671, 117.31249 7...        44238
# 8   MULTIPOLYGON (((121.88379 6.69138, 121.88380 6...        66097
# 9   MULTIPOLYGON (((122.98823 11.73079, 122.98824 ...        65786
# 10  MULTIPOLYGON (((122.49684 9.55607, 122.49685 9...       194989
# 11  MULTIPOLYGON (((123.27039 9.08460, 123.27040 9...       193299
# 12  MULTIPOLYGON (((125.06042 9.96466, 125.06043 9...        64444
# 13  MULTIPOLYGON (((123.57503 8.63343, 123.57462 8...       106189
# 14  MULTIPOLYGON (((125.39719 5.43791, 125.39719 5...       140681
# 15  MULTIPOLYGON (((124.24158 7.26286, 124.24233 7...        75975
#
#        percentiles
# 0         0-100000
# 1         0-100000
# 2   900000-1200000
# 3         0-100000
# 4    100000-200000
# 5    200000-300000
# 6    500000-600000
# 7         0-100000
# 8         0-100000
# 9         0-100000
# 10   100000-200000
# 11   100000-200000
# 12        0-100000
# 13        0-100000
# 14        0-100000
# 15        0-100000

# %%
regions_cases.dtypes
# Out:
# regions          object
# geometry       geometry
# covid_cases       int64
# percentiles    category
# dtype: object

# %% [markdown]
# **Additional step**: Convert the contents of the percentiles into string. Not doing so will not be read by the GEOJSON file.

# %%
regions_cases.percentiles = regions_cases.percentiles.astype(str)
regions_cases.dtypes
# Out:
# regions          object
# geometry       geometry
# covid_cases       int64
# percentiles      object
# dtype: object

# %% [markdown]
# # Save as GEOJSON file

# %%
regions_cases.to_file('regions_cases.geojson', driver='GeoJSON')
# Out:
# /Users/prinzmagtulis/.pyenv/versions/3.10.0/lib/python3.10/site-packages/geopandas/io/file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,

# %% [markdown]
# # Simplified file
#
# So we were successful in combining geometry files with our dataset, but the file is too big. We, therefore, use [mapshaper](https://mapshaper.org/) to simplify the precision of the map so that we have a smaller map size.
#
# Below is the simplified json file.

# %%
simplified_regions = gpd.read_file('simplified_regions.json')
simplified_regions

# %% [markdown]
# ## Convert to GEOJSON

# %%
simplified_regions.to_file('simplified_regions.geojson', driver='GeoJSON')

# %%
simplified_regions
