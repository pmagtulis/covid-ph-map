# %% [markdown]
# # Cleaning Covid data for Mapbox: municipal
#
# **Background**: We use Covid-19 cases data in the Philippines from data from the health department and shapefile processed through geopandas to create an interactive map.
#
# **Tools**: pandas, geopandas, Mapbox
#
# Updated as of Jan. 16, 2023

# %% [markdown]
# # Do your imports

# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import pandas as pd
import fuzzy_pandas as fpd

import shapely

pd.set_option('display.max_columns', None)

# %% [markdown]
# # Read your CSV

# %%
df= pd.read_csv('municipalities.csv')
df
# Out:
#                 ProvRes         CityMunRes  CityMunRes.1
# 0                  Abra  Bangued (Capital)          1226
# 1                  Abra            Boliney           199
# 2                  Abra              Bucay           350
# 3                  Abra             Bucloc           120
# 4                  Abra          Daguioman            91
# ...                 ...                ...           ...
# 1630  Zamboanga Sibugay       Roseller Lim           197
# 1631  Zamboanga Sibugay               Siay           455
# 1632  Zamboanga Sibugay            Talusan            58
# 1633  Zamboanga Sibugay              Titay           491
# 1634  Zamboanga Sibugay           Tungawan           287
#
# [1635 rows x 3 columns]

# %% [markdown]
# # Cleaning the data

# %% [markdown]
# ## Lowercase column headers

# %%
df.columns = df.columns.str.lower()
df.head(10)
# Out:
#   provres         citymunres  citymunres.1
# 0    Abra  Bangued (Capital)          1226
# 1    Abra            Boliney           199
# 2    Abra              Bucay           350
# 3    Abra             Bucloc           120
# 4    Abra          Daguioman            91
# 5    Abra            Danglas           131
# 6    Abra            Dolores           419
# 7    Abra             La Paz           311
# 8    Abra              Lacub            43
# 9    Abra        Lagangilang           314

# %% [markdown]
# ## Change names

# %%
df.citymunres = df.citymunres.str.replace('(Capital)', "", regex=False)
df.citymunres = df.citymunres.str.replace('Of', "of", regex=False)
df.provres = df.provres.str.replace('Samar (Western Samar)', 'Samar', regex=False)
df.provres = df.provres.str.replace('Cotabato (North Cotabato)', 'Cotabato', regex=False)
df.provres = df.provres.str.replace('Ncr', 'NCR', regex=False)
df.provres = df.provres.str.replace('Cotabato City (Not A Province)', 'Cotabato City', regex=False)
df.provres = df.provres.str.replace('City Of Isabela (Not A Province)', 'City of Isabela', regex=False)
df.citymunres = df.citymunres.str.replace(r'[(].*$', "", regex=True)

# %% [markdown]
# ## Look for NaN values

# %%
df.isna().sum()
# Out:
# provres         0
# citymunres      0
# citymunres.1    0
# dtype: int64

# %% [markdown]
# ## Rename columns
#
# This is again to match the shapefile column containing the provinces' names which is 'adm2_en'. We are also renaming the column containing the Covid-19 cases tally.

# %%
df= df.rename(columns={"provres": "province"})
df= df.rename(columns={"citymunres": "municipality"})
df= df.rename(columns={"citymunres.1": "covid_cases"})
df.head()
# Out:
#   province municipality  covid_cases
# 0     Abra     Bangued          1226
# 1     Abra      Boliney          199
# 2     Abra        Bucay          350
# 3     Abra       Bucloc          120
# 4     Abra    Daguioman           91

# %% [markdown]
# ## Merge province and municipality columns
#
# Make a new column containing both

# %%
df['territory'] = df.municipality + df.province
df
# Out:
#                province  municipality  covid_cases  \
# 0                  Abra      Bangued          1226
# 1                  Abra       Boliney          199
# 2                  Abra         Bucay          350
# 3                  Abra        Bucloc          120
# 4                  Abra     Daguioman           91
# ...                 ...           ...          ...
# 1630  Zamboanga Sibugay  Roseller Lim          197
# 1631  Zamboanga Sibugay          Siay          455
# 1632  Zamboanga Sibugay       Talusan           58
# 1633  Zamboanga Sibugay         Titay          491
# 1634  Zamboanga Sibugay      Tungawan          287
#
#                           territory
# 0                      Bangued Abra
# 1                       BolineyAbra
# 2                         BucayAbra
# 3                        BuclocAbra
# 4                     DaguiomanAbra
# ...                             ...
# 1630  Roseller LimZamboanga Sibugay
# 1631          SiayZamboanga Sibugay
# 1632       TalusanZamboanga Sibugay
# 1633         TitayZamboanga Sibugay
# 1634      TungawanZamboanga Sibugay
#
# [1635 rows x 4 columns]

# %% [markdown]
# # Geopandas
#
# ## Read through file

# %%
municipal = gpd.read_file('maps/phl_adminboundaries_candidate_adm3.zip')
municipal.head()
# Out:
#    Shape_Leng  Shape_Area       ADM3_EN   ADM3_PCODE ADM3_REF ADM3ALT1EN  \
# 0    1.601219    0.063496       Aborlan  PH175301000     None       None
# 1    1.078749    0.050232  Abra de Ilog  PH175101000     None       None
# 2    0.424301    0.006453        Abucay  PH030801000     None       None
# 3    0.566053    0.011343        Abulug  PH021501000     None       None
# 4    1.013649    0.026124        Abuyog  PH083701000     None       None
#
#   ADM3ALT2EN             ADM2_EN   ADM2_PCODE      ADM1_EN   ADM1_PCODE  \
# 0       None             Palawan  PH175300000  Region IV-B  PH170000000
# 1       None  Occidental Mindoro  PH175100000  Region IV-B  PH170000000
# 2       None              Bataan  PH030800000   Region III  PH030000000
# 3       None             Cagayan  PH021500000    Region II  PH020000000
# 4       None               Leyte  PH083700000  Region VIII  PH080000000
#
#              ADM0_EN ADM0_PCODE        date     validOn validTo  \
# 0  Philippines (the)         PH  2016-06-30  2020-05-29    None
# 1  Philippines (the)         PH  2016-06-30  2020-05-29    None
# 2  Philippines (the)         PH  2016-06-30  2020-05-29    None
# 3  Philippines (the)         PH  2016-06-30  2020-05-29    None
# 4  Philippines (the)         PH  2016-06-30  2020-05-29    None
#
#                                             geometry
# 0  MULTIPOLYGON (((118.58350 9.37700, 118.58398 9...
# 1  POLYGON ((120.58412 13.50198, 120.58420 13.501...
# 2  POLYGON ((120.49873 14.75614, 120.49891 14.755...
# 3  POLYGON ((121.43455 18.46651, 121.43502 18.466...
# 4  MULTIPOLYGON (((125.02684 10.73500, 125.02683 ...

# %% [markdown]
# ## Drop unncessary columns and lower headers

# %%
municipal = municipal.drop(['ADM3_PCODE', 'ADM3_REF','ADM3ALT1EN', 'ADM3ALT2EN', 'ADM2_PCODE', 'ADM1_PCODE', 'Shape_Leng', 'Shape_Area', 'ADM0_EN', 'date', 'validOn', 'validTo'], axis=1)
municipal.head()
# Out:
#         ADM3_EN             ADM2_EN      ADM1_EN ADM0_PCODE  \
# 0       Aborlan             Palawan  Region IV-B         PH
# 1  Abra de Ilog  Occidental Mindoro  Region IV-B         PH
# 2        Abucay              Bataan   Region III         PH
# 3        Abulug             Cagayan    Region II         PH
# 4        Abuyog               Leyte  Region VIII         PH
#
#                                             geometry
# 0  MULTIPOLYGON (((118.58350 9.37700, 118.58398 9...
# 1  POLYGON ((120.58412 13.50198, 120.58420 13.501...
# 2  POLYGON ((120.49873 14.75614, 120.49891 14.755...
# 3  POLYGON ((121.43455 18.46651, 121.43502 18.466...
# 4  MULTIPOLYGON (((125.02684 10.73500, 125.02683 ...

# %%
municipal = municipal.drop('ADM0_PCODE', axis=1)

# %%
municipal.columns = municipal.columns.str.lower()
municipal
# Out:
#              adm3_en             adm2_en      adm1_en  \
# 0            Aborlan             Palawan  Region IV-B
# 1       Abra de Ilog  Occidental Mindoro  Region IV-B
# 2             Abucay              Bataan   Region III
# 3             Abulug             Cagayan    Region II
# 4             Abuyog               Leyte  Region VIII
# ...              ...                 ...          ...
# 1642  Zamboanga City   Zamboanga del Sur    Region IX
# 1643    Zamboanguita     Negros Oriental   Region VII
# 1644        Zaragoza         Nueva Ecija   Region III
# 1645         Zarraga              Iloilo    Region VI
# 1646       Zumarraga               Samar  Region VIII
#
#                                                geometry
# 0     MULTIPOLYGON (((118.58350 9.37700, 118.58398 9...
# 1     POLYGON ((120.58412 13.50198, 120.58420 13.501...
# 2     POLYGON ((120.49873 14.75614, 120.49891 14.755...
# 3     POLYGON ((121.43455 18.46651, 121.43502 18.466...
# 4     MULTIPOLYGON (((125.02684 10.73500, 125.02683 ...
# ...                                                 ...
# 1642  MULTIPOLYGON (((122.05710 6.87274, 122.05724 6...
# 1643  POLYGON ((123.17078 9.22988, 123.18679 9.21804...
# 1644  POLYGON ((120.79780 15.48471, 120.80280 15.480...
# 1645  POLYGON ((122.63365 10.85890, 122.63857 10.857...
# 1646  MULTIPOLYGON (((124.87697 11.62089, 124.87698 ...
#
# [1647 rows x 4 columns]

# %% [markdown]
# ## Sorting
#
# Because of large number of cities and municipalities, we need to sort to make it easier for us to match with those in the dataset. We will be using the province column for this.

# %%
municipal = municipal.sort_values('adm2_en')
municipal.head()
# Out:
#      adm3_en adm2_en                           adm1_en  \
# 481  Danglas    Abra  Cordillera Administrative Region
# 525  Dolores    Abra  Cordillera Administrative Region
# 814     Luba    Abra  Cordillera Administrative Region
# 723   La Paz    Abra  Cordillera Administrative Region
# 150  Bangued    Abra  Cordillera Administrative Region
#
#                                               geometry
# 481  MULTIPOLYGON (((120.65654 17.64573, 120.65638 ...
# 525  POLYGON ((120.72760 17.66081, 120.72909 17.659...
# 814  POLYGON ((120.68143 17.39224, 120.68160 17.392...
# 723  POLYGON ((120.70876 17.71055, 120.70932 17.709...
# 150  POLYGON ((120.60875 17.62596, 120.61649 17.625...

# %% [markdown]
# ## Replacing names
#
# This is so the names of provinces and municipalities are consistent with that of our dataset which we will merge with this file. We did this for the dataset as well.

# %%
municipal.adm2_en = municipal.adm2_en.str.replace('Compostela Valley', "Davao de Oro", regex=False)
municipal.adm2_en = municipal.adm2_en.str.replace('NCR, City of Manila, First District', "NCR", regex=False)
municipal.adm2_en = municipal.adm2_en.str.replace('NCR, Second District', "NCR", regex=False)
municipal.adm2_en = municipal.adm2_en.str.replace('NCR, Third District', "NCR", regex=False)
municipal.adm2_en = municipal.adm2_en.str.replace('NCR, Fourth District', "NCR", regex=False)
municipal.adm3_en = municipal.adm3_en.str.replace('Ozamis City', "Ozamiz City", regex=False)
municipal.adm3_en = municipal.adm3_en.str.replace('Quiapo', "City of Manila", regex=False) #dummy for entire Manila.

# %% [markdown]
# ## Merge province and municipal columns

# %%
municipal['territory_2']= municipal.adm3_en + municipal.adm2_en
municipal.head()
# Out:
#      adm3_en adm2_en                           adm1_en  \
# 481  Danglas    Abra  Cordillera Administrative Region
# 525  Dolores    Abra  Cordillera Administrative Region
# 814     Luba    Abra  Cordillera Administrative Region
# 723   La Paz    Abra  Cordillera Administrative Region
# 150  Bangued    Abra  Cordillera Administrative Region
#
#                                               geometry  territory_2
# 481  MULTIPOLYGON (((120.65654 17.64573, 120.65638 ...  DanglasAbra
# 525  POLYGON ((120.72760 17.66081, 120.72909 17.659...  DoloresAbra
# 814  POLYGON ((120.68143 17.39224, 120.68160 17.392...     LubaAbra
# 723  POLYGON ((120.70876 17.71055, 120.70932 17.709...   La PazAbra
# 150  POLYGON ((120.60875 17.62596, 120.61649 17.625...  BanguedAbra

# %%
municipal.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
municipal.dtypes
# Out:
# adm3_en          object
# adm2_en          object
# adm1_en          object
# geometry       geometry
# territory_2      object
# dtype: object

# %%
municipal.territory_2= municipal.territory_2.astype(str)
df.territory= df.territory.astype(str)

# %% [markdown]
# ## Fuzzy pandas

# %%
#pd.set_option('display.max_rows', None)
final_df = fpd.fuzzy_merge(municipal, df,
                left_on=['territory_2'],
                right_on=['territory'],
                ignore_case=True,
                ignore_nonalpha=True,
                ignore_nonlatin=True,
                #join='full-outer',
                keep='all')
final_df
# Out:
# /opt/homebrew/lib/python3.10/site-packages/pandas/core/dtypes/inference.py:383: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   iter(obj)  # Can iterate over it.
# /opt/homebrew/lib/python3.10/site-packages/pandas/core/dtypes/inference.py:384: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   len(obj)  # Has a length associated with it.
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:117: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   s = iter(seq)
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:121: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   for i in range(min(nitems, len(seq)))
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:125: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if nitems < len(seq):
# /opt/homebrew/lib/python3.10/site-packages/pandas/core/dtypes/inference.py:383: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   iter(obj)  # Can iterate over it.
# /opt/homebrew/lib/python3.10/site-packages/pandas/core/dtypes/inference.py:384: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   len(obj)  # Has a length associated with it.
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:117: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   s = iter(seq)
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:121: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   for i in range(min(nitems, len(seq)))
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:125: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if nitems < len(seq):
#            adm3_en            adm2_en                           adm1_en  \
# 0          Danglas               Abra  Cordillera Administrative Region
# 1          Dolores               Abra  Cordillera Administrative Region
# 2             Luba               Abra  Cordillera Administrative Region
# 3           La Paz               Abra  Cordillera Administrative Region
# 4          Bangued               Abra  Cordillera Administrative Region
# ...            ...                ...                               ...
# 1627        Pitogo  Zamboanga del Sur                         Region IX
# 1628        Aurora  Zamboanga del Sur                         Region IX
# 1629     San Pablo  Zamboanga del Sur                         Region IX
# 1630      Dumingag  Zamboanga del Sur                         Region IX
# 1631  Margosatubig  Zamboanga del Sur                         Region IX
#
#                                                geometry  \
# 0     (POLYGON ((120.65653987700011 17.6457320440000...
# 1     POLYGON ((120.72760314700008 17.66080787500004...
# 2     POLYGON ((120.6814333860001 17.39223621900004,...
# 3     POLYGON ((120.70875978400011 17.71055038000003...
# 4     POLYGON ((120.6087521930001 17.625961226000072...
# ...                                                 ...
# 1627  (POLYGON ((123.32952880800008 7.36853027300003...
# 1628  POLYGON ((123.54540352700008 7.999042532000033...
# 1629  (POLYGON ((123.45762937900008 7.61576258600007...
# 1630  POLYGON ((123.27956563500004 8.236521383000024...
# 1631  (POLYGON ((123.18742779900003 7.61127261900003...
#
#                         territory_2           province  municipality  \
# 0                       DanglasAbra               Abra       Danglas
# 1                       DoloresAbra               Abra       Dolores
# 2                          LubaAbra               Abra          Luba
# 3                        La PazAbra               Abra        La Paz
# 4                       BanguedAbra               Abra      Bangued
# ...                             ...                ...           ...
# 1627        PitogoZamboanga del Sur  Zamboanga Del Sur        Pitogo
# 1628        AuroraZamboanga del Sur  Zamboanga Del Sur        Aurora
# 1629     San PabloZamboanga del Sur  Zamboanga Del Sur     San Pablo
# 1630      DumingagZamboanga del Sur  Zamboanga Del Sur      Dumingag
# 1631  MargosatubigZamboanga del Sur  Zamboanga Del Sur  Margosatubig
#
#       covid_cases                      territory
# 0             131                    DanglasAbra
# 1             419                    DoloresAbra
# 2             240                       LubaAbra
# 3             311                     La PazAbra
# 4            1226                   Bangued Abra
# ...           ...                            ...
# 1627          143        PitogoZamboanga Del Sur
# 1628          668        AuroraZamboanga Del Sur
# 1629          139     San PabloZamboanga Del Sur
# 1630          323      DumingagZamboanga Del Sur
# 1631          710  MargosatubigZamboanga Del Sur
#
# [1632 rows x 9 columns]

# %% [markdown]
# #### Note: 9,163 cases from different provinces did not have municipal locations.

# %% [markdown]
# ## Read population data

# %%
df2 = pd.read_excel('population.xlsx', sheet_name="municipality")
df2
# Out:
#              municipality         province  population
# 0          CITY OF MANILA              NCR     1846513
# 1     CITY OF MANDALUYONG              NCR      425758
# 2        CITY OF MARIKINA              NCR      456059
# 3           CITY OF PASIG              NCR      803159
# 4             QUEZON CITY              NCR     2960048
# ...                   ...              ...         ...
# 1629              TAGBINA  Surigao del Sur       41051
# 1630                 TAGO  Surigao del Sur       39831
# 1631      CITY OF TANDAG   Surigao del Sur       62669
# 1632      CITY OF ISABELA  City of Isabela      130379
# 1633        COTABATO CITY    Cotabato City      325079
#
# [1634 rows x 3 columns]

# %% [markdown]
# ## Clean data a bit

# %%
df2.municipality = df2.municipality.str.title() #capitalizes and lower case the rest of the name an
df2.municipality = df2.municipality.str.replace('Of', "of", regex=True)
df2.municipality = df2.municipality.str.replace('Del', "del", regex=True)
df2.municipality = df2.municipality.str.replace(r'[(].*$', "", regex=True) #removes all characters after (

# %% [markdown]
# ## Merge 'province' and 'municipal' columns

# %%
df2['territory_3']= df2.municipality + df2.province
df2
# Out:
#              municipality         province  population  \
# 0          City of Manila              NCR     1846513
# 1     City of Mandaluyong              NCR      425758
# 2        City of Marikina              NCR      456059
# 3           City of Pasig              NCR      803159
# 4             Quezon City              NCR     2960048
# ...                   ...              ...         ...
# 1629              Tagbina  Surigao del Sur       41051
# 1630                 Tago  Surigao del Sur       39831
# 1631      City of Tandag   Surigao del Sur       62669
# 1632      City of Isabela  City of Isabela      130379
# 1633        Cotabato City    Cotabato City      325079
#
#                          territory_3
# 0                  City of ManilaNCR
# 1             City of MandaluyongNCR
# 2                City of MarikinaNCR
# 3                   City of PasigNCR
# 4                     Quezon CityNCR
# ...                              ...
# 1629          TagbinaSurigao del Sur
# 1630             TagoSurigao del Sur
# 1631  City of Tandag Surigao del Sur
# 1632  City of IsabelaCity of Isabela
# 1633      Cotabato CityCotabato City
#
# [1634 rows x 4 columns]

# %%
df2.territory_3= df2.territory_3.astype(str)

# %% [markdown]
# ## Fuzzy pandas... again
#
# This time to combine existing df with our population data.

# %%
final_df2 = fpd.fuzzy_merge(final_df, df2,
                left_on=['territory'],
                right_on=['territory_3'],
                ignore_case=True,
                ignore_nonalpha=True,
                ignore_nonlatin=True,
                #join='full-outer',
                keep='all')
final_df2
# Out:
# /opt/homebrew/lib/python3.10/site-packages/pandas/core/dtypes/inference.py:383: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   iter(obj)  # Can iterate over it.
# /opt/homebrew/lib/python3.10/site-packages/pandas/core/dtypes/inference.py:384: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   len(obj)  # Has a length associated with it.
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:117: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   s = iter(seq)
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:121: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   for i in range(min(nitems, len(seq)))
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:125: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if nitems < len(seq):
# /opt/homebrew/lib/python3.10/site-packages/pandas/core/dtypes/inference.py:383: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   iter(obj)  # Can iterate over it.
# /opt/homebrew/lib/python3.10/site-packages/pandas/core/dtypes/inference.py:384: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   len(obj)  # Has a length associated with it.
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:117: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   s = iter(seq)
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:121: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   for i in range(min(nitems, len(seq)))
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:125: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if nitems < len(seq):
#            adm3_en            adm2_en                           adm1_en  \
# 0          Danglas               Abra  Cordillera Administrative Region
# 1          Dolores               Abra  Cordillera Administrative Region
# 2             Luba               Abra  Cordillera Administrative Region
# 3           La Paz               Abra  Cordillera Administrative Region
# 4          Bangued               Abra  Cordillera Administrative Region
# ...            ...                ...                               ...
# 1627        Pitogo  Zamboanga del Sur                         Region IX
# 1628        Aurora  Zamboanga del Sur                         Region IX
# 1629     San Pablo  Zamboanga del Sur                         Region IX
# 1630      Dumingag  Zamboanga del Sur                         Region IX
# 1631  Margosatubig  Zamboanga del Sur                         Region IX
#
#                                                geometry  \
# 0     (POLYGON ((120.65653987700011 17.6457320440000...
# 1     POLYGON ((120.72760314700008 17.66080787500004...
# 2     POLYGON ((120.6814333860001 17.39223621900004,...
# 3     POLYGON ((120.70875978400011 17.71055038000003...
# 4     POLYGON ((120.6087521930001 17.625961226000072...
# ...                                                 ...
# 1627  (POLYGON ((123.32952880800008 7.36853027300003...
# 1628  POLYGON ((123.54540352700008 7.999042532000033...
# 1629  (POLYGON ((123.45762937900008 7.61576258600007...
# 1630  POLYGON ((123.27956563500004 8.236521383000024...
# 1631  (POLYGON ((123.18742779900003 7.61127261900003...
#
#                         territory_2           province  municipality  \
# 0                       DanglasAbra               Abra       Danglas
# 1                       DoloresAbra               Abra       Dolores
# 2                          LubaAbra               Abra          Luba
# 3                        La PazAbra               Abra        La Paz
# 4                       BanguedAbra               Abra      Bangued
# ...                             ...                ...           ...
# 1627        PitogoZamboanga del Sur  Zamboanga Del Sur        Pitogo
# 1628        AuroraZamboanga del Sur  Zamboanga Del Sur        Aurora
# 1629     San PabloZamboanga del Sur  Zamboanga Del Sur     San Pablo
# 1630      DumingagZamboanga del Sur  Zamboanga Del Sur      Dumingag
# 1631  MargosatubigZamboanga del Sur  Zamboanga Del Sur  Margosatubig
#
#       covid_cases                      territory  municipality  \
# 0             131                    DanglasAbra       Danglas
# 1             419                    DoloresAbra       Dolores
# 2             240                       LubaAbra          Luba
# 3             311                     La PazAbra        La Paz
# 4            1226                   Bangued Abra       Bangued
# ...           ...                            ...           ...
# 1627          143        PitogoZamboanga Del Sur        Pitogo
# 1628          668        AuroraZamboanga Del Sur        Aurora
# 1629          139     San PabloZamboanga Del Sur     San Pablo
# 1630          323      DumingagZamboanga Del Sur      Dumingag
# 1631          710  MargosatubigZamboanga Del Sur  Margosatubig
#
#                province  population                    territory_3
# 0                  Abra        4074                    DanglasAbra
# 1                  Abra       11512                    DoloresAbra
# 2                  Abra        6518                       LubaAbra
# 3                  Abra       16493                     La PazAbra
# 4                  Abra       50382                    BanguedAbra
# ...                 ...         ...                            ...
# 1627  Zamboanga del Sur       27516        PitogoZamboanga del Sur
# 1628  Zamboanga del Sur       52995        AuroraZamboanga del Sur
# 1629  Zamboanga del Sur       26648     San PabloZamboanga del Sur
# 1630  Zamboanga del Sur       48881      DumingagZamboanga del Sur
# 1631  Zamboanga del Sur       38660  MargosatubigZamboanga del Sur
#
# [1632 rows x 13 columns]

# %% [markdown]
# ## Drop extra columns

# %%
final_df2 = final_df2.drop(['adm2_en', 'adm3_en', 'territory_2', 'territory', 'territory_3'], axis=1)
final_df2
# Out:
# /opt/homebrew/lib/python3.10/site-packages/pandas/core/dtypes/inference.py:383: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   iter(obj)  # Can iterate over it.
# /opt/homebrew/lib/python3.10/site-packages/pandas/core/dtypes/inference.py:384: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   len(obj)  # Has a length associated with it.
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:117: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   s = iter(seq)
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:121: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   for i in range(min(nitems, len(seq)))
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:125: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if nitems < len(seq):
# /opt/homebrew/lib/python3.10/site-packages/pandas/core/dtypes/inference.py:383: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   iter(obj)  # Can iterate over it.
# /opt/homebrew/lib/python3.10/site-packages/pandas/core/dtypes/inference.py:384: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   len(obj)  # Has a length associated with it.
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:117: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   s = iter(seq)
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:121: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   for i in range(min(nitems, len(seq)))
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:125: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if nitems < len(seq):
#                                adm1_en  \
# 0     Cordillera Administrative Region
# 1     Cordillera Administrative Region
# 2     Cordillera Administrative Region
# 3     Cordillera Administrative Region
# 4     Cordillera Administrative Region
# ...                                ...
# 1627                         Region IX
# 1628                         Region IX
# 1629                         Region IX
# 1630                         Region IX
# 1631                         Region IX
#
#                                                geometry           province  \
# 0     (POLYGON ((120.65653987700011 17.6457320440000...               Abra
# 1     POLYGON ((120.72760314700008 17.66080787500004...               Abra
# 2     POLYGON ((120.6814333860001 17.39223621900004,...               Abra
# 3     POLYGON ((120.70875978400011 17.71055038000003...               Abra
# 4     POLYGON ((120.6087521930001 17.625961226000072...               Abra
# ...                                                 ...                ...
# 1627  (POLYGON ((123.32952880800008 7.36853027300003...  Zamboanga Del Sur
# 1628  POLYGON ((123.54540352700008 7.999042532000033...  Zamboanga Del Sur
# 1629  (POLYGON ((123.45762937900008 7.61576258600007...  Zamboanga Del Sur
# 1630  POLYGON ((123.27956563500004 8.236521383000024...  Zamboanga Del Sur
# 1631  (POLYGON ((123.18742779900003 7.61127261900003...  Zamboanga Del Sur
#
#       municipality  covid_cases  municipality           province  population
# 0          Danglas          131       Danglas               Abra        4074
# 1          Dolores          419       Dolores               Abra       11512
# 2             Luba          240          Luba               Abra        6518
# 3           La Paz          311        La Paz               Abra       16493
# 4         Bangued          1226       Bangued               Abra       50382
# ...            ...          ...           ...                ...         ...
# 1627        Pitogo          143        Pitogo  Zamboanga del Sur       27516
# 1628        Aurora          668        Aurora  Zamboanga del Sur       52995
# 1629     San Pablo          139     San Pablo  Zamboanga del Sur       26648
# 1630      Dumingag          323      Dumingag  Zamboanga del Sur       48881
# 1631  Margosatubig          710  Margosatubig  Zamboanga del Sur       38660
#
# [1632 rows x 8 columns]

# %% [markdown]
# ## Rename columns
#
# We are renaming the columns so that we can drop redundant ones with the same names.

# %%
final_df2.columns= ['adm1_en', 'geometry', 'province', 'municipality', 'covid_cases', 'municipality2', 'province2', 'population']
final_df2 = final_df2.drop(['municipality2', 'province2'], axis=1)
final_df2
# Out:
# /opt/homebrew/lib/python3.10/site-packages/pandas/core/dtypes/inference.py:383: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   iter(obj)  # Can iterate over it.
# /opt/homebrew/lib/python3.10/site-packages/pandas/core/dtypes/inference.py:384: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   len(obj)  # Has a length associated with it.
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:117: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   s = iter(seq)
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:121: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   for i in range(min(nitems, len(seq)))
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:125: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if nitems < len(seq):
# /opt/homebrew/lib/python3.10/site-packages/pandas/core/dtypes/inference.py:383: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   iter(obj)  # Can iterate over it.
# /opt/homebrew/lib/python3.10/site-packages/pandas/core/dtypes/inference.py:384: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   len(obj)  # Has a length associated with it.
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:117: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   s = iter(seq)
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:121: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   for i in range(min(nitems, len(seq)))
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:125: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if nitems < len(seq):
#                                adm1_en  \
# 0     Cordillera Administrative Region
# 1     Cordillera Administrative Region
# 2     Cordillera Administrative Region
# 3     Cordillera Administrative Region
# 4     Cordillera Administrative Region
# ...                                ...
# 1627                         Region IX
# 1628                         Region IX
# 1629                         Region IX
# 1630                         Region IX
# 1631                         Region IX
#
#                                                geometry           province  \
# 0     (POLYGON ((120.65653987700011 17.6457320440000...               Abra
# 1     POLYGON ((120.72760314700008 17.66080787500004...               Abra
# 2     POLYGON ((120.6814333860001 17.39223621900004,...               Abra
# 3     POLYGON ((120.70875978400011 17.71055038000003...               Abra
# 4     POLYGON ((120.6087521930001 17.625961226000072...               Abra
# ...                                                 ...                ...
# 1627  (POLYGON ((123.32952880800008 7.36853027300003...  Zamboanga Del Sur
# 1628  POLYGON ((123.54540352700008 7.999042532000033...  Zamboanga Del Sur
# 1629  (POLYGON ((123.45762937900008 7.61576258600007...  Zamboanga Del Sur
# 1630  POLYGON ((123.27956563500004 8.236521383000024...  Zamboanga Del Sur
# 1631  (POLYGON ((123.18742779900003 7.61127261900003...  Zamboanga Del Sur
#
#       municipality  covid_cases  population
# 0          Danglas          131        4074
# 1          Dolores          419       11512
# 2             Luba          240        6518
# 3           La Paz          311       16493
# 4         Bangued          1226       50382
# ...            ...          ...         ...
# 1627        Pitogo          143       27516
# 1628        Aurora          668       52995
# 1629     San Pablo          139       26648
# 1630      Dumingag          323       48881
# 1631  Margosatubig          710       38660
#
# [1632 rows x 6 columns]

# %% [markdown]
# ## Compute for population ratio
#
# We do this by dividing the number of Covid-19 cases to total population per municipality and then multiply by 10,000. That would give us cases per 10,000 people in the area.

# %%
final_df2 ['case_per_pop'] = final_df2.covid_cases / final_df2.population * 10000
final_df2 = final_df2.round(1)
final_df2.head()
# Out:
# /opt/homebrew/lib/python3.10/site-packages/pandas/core/dtypes/inference.py:383: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   iter(obj)  # Can iterate over it.
# /opt/homebrew/lib/python3.10/site-packages/pandas/core/dtypes/inference.py:384: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   len(obj)  # Has a length associated with it.
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:117: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   s = iter(seq)
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:121: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   for i in range(min(nitems, len(seq)))
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:125: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if nitems < len(seq):
# /opt/homebrew/lib/python3.10/site-packages/pandas/core/dtypes/inference.py:383: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   iter(obj)  # Can iterate over it.
# /opt/homebrew/lib/python3.10/site-packages/pandas/core/dtypes/inference.py:384: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   len(obj)  # Has a length associated with it.
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:117: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   s = iter(seq)
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:121: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   for i in range(min(nitems, len(seq)))
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:125: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if nitems < len(seq):
#                             adm1_en  \
# 0  Cordillera Administrative Region
# 1  Cordillera Administrative Region
# 2  Cordillera Administrative Region
# 3  Cordillera Administrative Region
# 4  Cordillera Administrative Region
#
#                                             geometry province municipality  \
# 0  (POLYGON ((120.65653987700011 17.6457320440000...     Abra      Danglas
# 1  POLYGON ((120.72760314700008 17.66080787500004...     Abra      Dolores
# 2  POLYGON ((120.6814333860001 17.39223621900004,...     Abra         Luba
# 3  POLYGON ((120.70875978400011 17.71055038000003...     Abra       La Paz
# 4  POLYGON ((120.6087521930001 17.625961226000072...     Abra     Bangued
#
#    covid_cases  population  case_per_pop
# 0          131        4074         321.6
# 1          419       11512         364.0
# 2          240        6518         368.2
# 3          311       16493         188.6
# 4         1226       50382         243.3

# %%
final_df2.sort_values('case_per_pop', ascending=False)
# Out:
# /opt/homebrew/lib/python3.10/site-packages/pandas/core/dtypes/inference.py:383: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   iter(obj)  # Can iterate over it.
# /opt/homebrew/lib/python3.10/site-packages/pandas/core/dtypes/inference.py:384: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   len(obj)  # Has a length associated with it.
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:117: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   s = iter(seq)
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:121: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   for i in range(min(nitems, len(seq)))
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:125: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if nitems < len(seq):
# /opt/homebrew/lib/python3.10/site-packages/pandas/core/dtypes/inference.py:383: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   iter(obj)  # Can iterate over it.
# /opt/homebrew/lib/python3.10/site-packages/pandas/core/dtypes/inference.py:384: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   len(obj)  # Has a length associated with it.
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:117: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   s = iter(seq)
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:121: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   for i in range(min(nitems, len(seq)))
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:125: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if nitems < len(seq):
#                                               adm1_en  \
# 312                                         Region II
# 1028                          National Capital Region
# 1024                          National Capital Region
# 1022                          National Capital Region
# 1026                          National Capital Region
# ...                                               ...
# 1544  Bangsamoro Autonomous Region in Muslim Mindanao
# 129   Bangsamoro Autonomous Region in Muslim Mindanao
# 829   Bangsamoro Autonomous Region in Muslim Mindanao
# 1477  Bangsamoro Autonomous Region in Muslim Mindanao
# 1537  Bangsamoro Autonomous Region in Muslim Mindanao
#
#                                                geometry       province  \
# 312   POLYGON ((121.0356007790001 18.620390781000026...        Cagayan
# 1028  POLYGON ((121.02626267700009 14.61227373300005...            NCR
# 1024  POLYGON ((121.0699916430001 14.552272799000036...            NCR
# 1022  POLYGON ((121.03467973800002 14.56724763500005...            NCR
# 1026  POLYGON ((120.98042364000003 14.56156389600005...            NCR
# ...                                                 ...            ...
# 1544  (POLYGON ((120.45063690400002 5.15174066500003...      Tawi-Tawi
# 129   (POLYGON ((121.99379767100004 6.28772321100007...        Basilan
# 829   POLYGON ((124.62352208900006 7.888021772000059...  Lanao Del Sur
# 1477  (POLYGON ((121.01278876900005 5.68534327400004...           Sulu
# 1537  (POLYGON ((118.4009098890001 6.878896047000069...      Tawi-Tawi
#
#           municipality  covid_cases  population  case_per_pop
# 312     Santa Praxedes          864        4434        1948.6
# 1028  City of San Juan        24051      126347        1903.6
# 1024           Pateros        10815       65227        1658.1
# 1022    City of Makati        95589      629616        1518.2
# 1026        Pasay City        58549      440656        1328.7
# ...                ...          ...         ...           ...
# 1544       South Ubian            6       29583           2.0
# 129        Tabuan-Lasa            5       29327           1.7
# 829           Bumbaran            2       12124           1.6
# 1477             Tapul            3       20799           1.4
# 1537            Mapun             3       30038           1.0
#
# [1632 rows x 7 columns]

# %% [markdown]
# ## Create bins for cases
#
# The bins will allow us to categorize the number of cases, necessary for mapping later.

# %%
final_df2['percentiles'] = pd.cut(np.array(final_df2['case_per_pop']),
       [0, 201, 401, 601, 801, 1001, 1201, 1401, 1601, 1801, 2000], labels=["0-200", "201-400", "401-600", "601-800", "801-1000", "1001-1200", "1201-1400", "1401-1600", "1601-1800", "1801-2000"])
final_df2
# Out:
# /opt/homebrew/lib/python3.10/site-packages/pandas/core/dtypes/inference.py:383: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   iter(obj)  # Can iterate over it.
# /opt/homebrew/lib/python3.10/site-packages/pandas/core/dtypes/inference.py:384: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   len(obj)  # Has a length associated with it.
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:117: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   s = iter(seq)
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:121: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   for i in range(min(nitems, len(seq)))
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:125: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if nitems < len(seq):
# /opt/homebrew/lib/python3.10/site-packages/pandas/core/dtypes/inference.py:383: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   iter(obj)  # Can iterate over it.
# /opt/homebrew/lib/python3.10/site-packages/pandas/core/dtypes/inference.py:384: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   len(obj)  # Has a length associated with it.
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:117: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   s = iter(seq)
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:121: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   for i in range(min(nitems, len(seq)))
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:125: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if nitems < len(seq):
#                                adm1_en  \
# 0     Cordillera Administrative Region
# 1     Cordillera Administrative Region
# 2     Cordillera Administrative Region
# 3     Cordillera Administrative Region
# 4     Cordillera Administrative Region
# ...                                ...
# 1627                         Region IX
# 1628                         Region IX
# 1629                         Region IX
# 1630                         Region IX
# 1631                         Region IX
#
#                                                geometry           province  \
# 0     (POLYGON ((120.65653987700011 17.6457320440000...               Abra
# 1     POLYGON ((120.72760314700008 17.66080787500004...               Abra
# 2     POLYGON ((120.6814333860001 17.39223621900004,...               Abra
# 3     POLYGON ((120.70875978400011 17.71055038000003...               Abra
# 4     POLYGON ((120.6087521930001 17.625961226000072...               Abra
# ...                                                 ...                ...
# 1627  (POLYGON ((123.32952880800008 7.36853027300003...  Zamboanga Del Sur
# 1628  POLYGON ((123.54540352700008 7.999042532000033...  Zamboanga Del Sur
# 1629  (POLYGON ((123.45762937900008 7.61576258600007...  Zamboanga Del Sur
# 1630  POLYGON ((123.27956563500004 8.236521383000024...  Zamboanga Del Sur
# 1631  (POLYGON ((123.18742779900003 7.61127261900003...  Zamboanga Del Sur
#
#       municipality  covid_cases  population  case_per_pop percentiles
# 0          Danglas          131        4074         321.6     201-400
# 1          Dolores          419       11512         364.0     201-400
# 2             Luba          240        6518         368.2     201-400
# 3           La Paz          311       16493         188.6       0-200
# 4         Bangued          1226       50382         243.3     201-400
# ...            ...          ...         ...           ...         ...
# 1627        Pitogo          143       27516          52.0       0-200
# 1628        Aurora          668       52995         126.0       0-200
# 1629     San Pablo          139       26648          52.2       0-200
# 1630      Dumingag          323       48881          66.1       0-200
# 1631  Margosatubig          710       38660         183.7       0-200
#
# [1632 rows x 8 columns]

# %% [markdown]
# **Additional step**: Convert the contents of the percentiles into string. Not doing so will not be read by the GEOJSON file.

# %%
final_df2.percentiles = final_df2.percentiles.astype(str)
final_df2
# Out:
# /opt/homebrew/lib/python3.10/site-packages/pandas/core/dtypes/inference.py:383: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   iter(obj)  # Can iterate over it.
# /opt/homebrew/lib/python3.10/site-packages/pandas/core/dtypes/inference.py:384: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   len(obj)  # Has a length associated with it.
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:117: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   s = iter(seq)
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:121: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   for i in range(min(nitems, len(seq)))
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:125: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if nitems < len(seq):
# /opt/homebrew/lib/python3.10/site-packages/pandas/core/dtypes/inference.py:383: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   iter(obj)  # Can iterate over it.
# /opt/homebrew/lib/python3.10/site-packages/pandas/core/dtypes/inference.py:384: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   len(obj)  # Has a length associated with it.
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:117: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   s = iter(seq)
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:121: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   for i in range(min(nitems, len(seq)))
# /opt/homebrew/lib/python3.10/site-packages/pandas/io/formats/printing.py:125: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if nitems < len(seq):
#                                adm1_en  \
# 0     Cordillera Administrative Region
# 1     Cordillera Administrative Region
# 2     Cordillera Administrative Region
# 3     Cordillera Administrative Region
# 4     Cordillera Administrative Region
# ...                                ...
# 1627                         Region IX
# 1628                         Region IX
# 1629                         Region IX
# 1630                         Region IX
# 1631                         Region IX
#
#                                                geometry           province  \
# 0     (POLYGON ((120.65653987700011 17.6457320440000...               Abra
# 1     POLYGON ((120.72760314700008 17.66080787500004...               Abra
# 2     POLYGON ((120.6814333860001 17.39223621900004,...               Abra
# 3     POLYGON ((120.70875978400011 17.71055038000003...               Abra
# 4     POLYGON ((120.6087521930001 17.625961226000072...               Abra
# ...                                                 ...                ...
# 1627  (POLYGON ((123.32952880800008 7.36853027300003...  Zamboanga Del Sur
# 1628  POLYGON ((123.54540352700008 7.999042532000033...  Zamboanga Del Sur
# 1629  (POLYGON ((123.45762937900008 7.61576258600007...  Zamboanga Del Sur
# 1630  POLYGON ((123.27956563500004 8.236521383000024...  Zamboanga Del Sur
# 1631  (POLYGON ((123.18742779900003 7.61127261900003...  Zamboanga Del Sur
#
#       municipality  covid_cases  population  case_per_pop percentiles
# 0          Danglas          131        4074         321.6     201-400
# 1          Dolores          419       11512         364.0     201-400
# 2             Luba          240        6518         368.2     201-400
# 3           La Paz          311       16493         188.6       0-200
# 4         Bangued          1226       50382         243.3     201-400
# ...            ...          ...         ...           ...         ...
# 1627        Pitogo          143       27516          52.0       0-200
# 1628        Aurora          668       52995         126.0       0-200
# 1629     San Pablo          139       26648          52.2       0-200
# 1630      Dumingag          323       48881          66.1       0-200
# 1631  Margosatubig          710       38660         183.7       0-200
#
# [1632 rows x 8 columns]

# %% [markdown]
# # Convert 'geometry' column back to a geopandas df
#
# We lost that when we ran fuzzy pandas.

# %%
final_df2 = gpd.GeoDataFrame(final_df2, crs="EPSG:4326", geometry=final_df2.geometry)

# %%
final_df2
# Out:
#                                adm1_en  \
# 0     Cordillera Administrative Region
# 1     Cordillera Administrative Region
# 2     Cordillera Administrative Region
# 3     Cordillera Administrative Region
# 4     Cordillera Administrative Region
# ...                                ...
# 1627                         Region IX
# 1628                         Region IX
# 1629                         Region IX
# 1630                         Region IX
# 1631                         Region IX
#
#                                                geometry           province  \
# 0     MULTIPOLYGON (((120.65654 17.64573, 120.65638 ...               Abra
# 1     POLYGON ((120.72760 17.66081, 120.72909 17.659...               Abra
# 2     POLYGON ((120.68143 17.39224, 120.68160 17.392...               Abra
# 3     POLYGON ((120.70876 17.71055, 120.70932 17.709...               Abra
# 4     POLYGON ((120.60875 17.62596, 120.61649 17.625...               Abra
# ...                                                 ...                ...
# 1627  MULTIPOLYGON (((123.32953 7.36853, 123.32910 7...  Zamboanga Del Sur
# 1628  POLYGON ((123.54540 7.99904, 123.54673 7.99865...  Zamboanga Del Sur
# 1629  MULTIPOLYGON (((123.45763 7.61576, 123.45765 7...  Zamboanga Del Sur
# 1630  POLYGON ((123.27957 8.23652, 123.30633 8.23514...  Zamboanga Del Sur
# 1631  MULTIPOLYGON (((123.18743 7.61127, 123.18743 7...  Zamboanga Del Sur
#
#       municipality  covid_cases  population  case_per_pop percentiles
# 0          Danglas          131        4074         321.6     201-400
# 1          Dolores          419       11512         364.0     201-400
# 2             Luba          240        6518         368.2     201-400
# 3           La Paz          311       16493         188.6       0-200
# 4         Bangued          1226       50382         243.3     201-400
# ...            ...          ...         ...           ...         ...
# 1627        Pitogo          143       27516          52.0       0-200
# 1628        Aurora          668       52995         126.0       0-200
# 1629     San Pablo          139       26648          52.2       0-200
# 1630      Dumingag          323       48881          66.1       0-200
# 1631  Margosatubig          710       38660         183.7       0-200
#
# [1632 rows x 8 columns]

# %% [markdown]
# # Save as GEOJSON file

# %%
final_df2.to_file('municipal.geojson', driver='GeoJSON')

# %% [markdown]
# # Simplified file
#
# So we were successful in combining geometry files with our dataset, but the file is too big. We, therefore, use [mapshaper](https://mapshaper.org/) to simplify the precision of the map so that we have a smaller map size.
#
# Below is the simplified json file.

# %%
simplified = gpd.read_file('municipal.json')
simplified
# Out:
#                                adm1_en           province  municipality  \
# 0     Cordillera Administrative Region               Abra       Danglas
# 1     Cordillera Administrative Region               Abra       Dolores
# 2     Cordillera Administrative Region               Abra          Luba
# 3     Cordillera Administrative Region               Abra        La Paz
# 4     Cordillera Administrative Region               Abra      Bangued
# ...                                ...                ...           ...
# 1627                         Region IX  Zamboanga Del Sur        Pitogo
# 1628                         Region IX  Zamboanga Del Sur        Aurora
# 1629                         Region IX  Zamboanga Del Sur     San Pablo
# 1630                         Region IX  Zamboanga Del Sur      Dumingag
# 1631                         Region IX  Zamboanga Del Sur  Margosatubig
#
#       covid_cases  population  case_per_pop percentiles  \
# 0             131        4074         321.6     201-400
# 1             419       11512         364.0     201-400
# 2             240        6518         368.2     201-400
# 3             311       16493         188.6       0-200
# 4            1226       50382         243.3     201-400
# ...           ...         ...           ...         ...
# 1627          143       27516          52.0       0-200
# 1628          668       52995         126.0       0-200
# 1629          139       26648          52.2       0-200
# 1630          323       48881          66.1       0-200
# 1631          710       38660         183.7       0-200
#
#                                                geometry
# 0     MULTIPOLYGON (((120.65654 17.64573, 120.65656 ...
# 1     POLYGON ((120.77803 17.66674, 120.76612 17.666...
# 2     POLYGON ((120.68189 17.39219, 120.68134 17.392...
# 3     POLYGON ((120.70876 17.71055, 120.70783 17.710...
# 4     POLYGON ((120.61921 17.62751, 120.61748 17.626...
# ...                                                 ...
# 1627  MULTIPOLYGON (((123.32953 7.36853, 123.32953 7...
# 1628  POLYGON ((123.64055 7.98886, 123.63926 7.98924...
# 1629  MULTIPOLYGON (((123.45763 7.61576, 123.45767 7...
# 1630  POLYGON ((123.38109 8.22467, 123.37773 8.22477...
# 1631  MULTIPOLYGON (((123.18743 7.61127, 123.18685 7...
#
# [1632 rows x 8 columns]

# %% [markdown]
# ## Convert to GEOJSON

# %%
simplified.to_file('simplified_municipalities.geojson', driver='GeoJSON')

# %%
simplified
# Out:
#                                adm1_en           province  municipality  \
# 0     Cordillera Administrative Region               Abra       Danglas
# 1     Cordillera Administrative Region               Abra       Dolores
# 2     Cordillera Administrative Region               Abra          Luba
# 3     Cordillera Administrative Region               Abra        La Paz
# 4     Cordillera Administrative Region               Abra      Bangued
# ...                                ...                ...           ...
# 1627                         Region IX  Zamboanga Del Sur        Pitogo
# 1628                         Region IX  Zamboanga Del Sur        Aurora
# 1629                         Region IX  Zamboanga Del Sur     San Pablo
# 1630                         Region IX  Zamboanga Del Sur      Dumingag
# 1631                         Region IX  Zamboanga Del Sur  Margosatubig
#
#       covid_cases  population  case_per_pop percentiles  \
# 0             131        4074         321.6     201-400
# 1             419       11512         364.0     201-400
# 2             240        6518         368.2     201-400
# 3             311       16493         188.6       0-200
# 4            1226       50382         243.3     201-400
# ...           ...         ...           ...         ...
# 1627          143       27516          52.0       0-200
# 1628          668       52995         126.0       0-200
# 1629          139       26648          52.2       0-200
# 1630          323       48881          66.1       0-200
# 1631          710       38660         183.7       0-200
#
#                                                geometry
# 0     MULTIPOLYGON (((120.65654 17.64573, 120.65656 ...
# 1     POLYGON ((120.77803 17.66674, 120.76612 17.666...
# 2     POLYGON ((120.68189 17.39219, 120.68134 17.392...
# 3     POLYGON ((120.70876 17.71055, 120.70783 17.710...
# 4     POLYGON ((120.61921 17.62751, 120.61748 17.626...
# ...                                                 ...
# 1627  MULTIPOLYGON (((123.32953 7.36853, 123.32953 7...
# 1628  POLYGON ((123.64055 7.98886, 123.63926 7.98924...
# 1629  MULTIPOLYGON (((123.45763 7.61576, 123.45767 7...
# 1630  POLYGON ((123.38109 8.22467, 123.37773 8.22477...
# 1631  MULTIPOLYGON (((123.18743 7.61127, 123.18685 7...
#
# [1632 rows x 8 columns]

# %% [markdown]
# ## Clean CSV for uploading to website

# %%
simplified = simplified.drop(['population', 'geometry', 'percentiles'], axis=1)
simplified.columns = ['Region', 'Province', 'Municipality', 'Covid-19 cases', 'Case per population']
simplified
# Out:
#                                 Region           Province  Municipality  \
# 0     Cordillera Administrative Region               Abra       Danglas
# 1     Cordillera Administrative Region               Abra       Dolores
# 2     Cordillera Administrative Region               Abra          Luba
# 3     Cordillera Administrative Region               Abra        La Paz
# 4     Cordillera Administrative Region               Abra      Bangued
# ...                                ...                ...           ...
# 1627                         Region IX  Zamboanga Del Sur        Pitogo
# 1628                         Region IX  Zamboanga Del Sur        Aurora
# 1629                         Region IX  Zamboanga Del Sur     San Pablo
# 1630                         Region IX  Zamboanga Del Sur      Dumingag
# 1631                         Region IX  Zamboanga Del Sur  Margosatubig
#
#       Covid-19 cases  Case per population
# 0                131                321.6
# 1                419                364.0
# 2                240                368.2
# 3                311                188.6
# 4               1226                243.3
# ...              ...                  ...
# 1627             143                 52.0
# 1628             668                126.0
# 1629             139                 52.2
# 1630             323                 66.1
# 1631             710                183.7
#
# [1632 rows x 5 columns]

# %%
simplified = simplified[['Municipality', 'Province', 'Region', 'Covid-19 cases', 'Case per population']]
simplified
# Out:
#       Municipality           Province                            Region  \
# 0          Danglas               Abra  Cordillera Administrative Region
# 1          Dolores               Abra  Cordillera Administrative Region
# 2             Luba               Abra  Cordillera Administrative Region
# 3           La Paz               Abra  Cordillera Administrative Region
# 4         Bangued                Abra  Cordillera Administrative Region
# ...            ...                ...                               ...
# 1627        Pitogo  Zamboanga Del Sur                         Region IX
# 1628        Aurora  Zamboanga Del Sur                         Region IX
# 1629     San Pablo  Zamboanga Del Sur                         Region IX
# 1630      Dumingag  Zamboanga Del Sur                         Region IX
# 1631  Margosatubig  Zamboanga Del Sur                         Region IX
#
#       Covid-19 cases  Case per population
# 0                131                321.6
# 1                419                364.0
# 2                240                368.2
# 3                311                188.6
# 4               1226                243.3
# ...              ...                  ...
# 1627             143                 52.0
# 1628             668                126.0
# 1629             139                 52.2
# 1630             323                 66.1
# 1631             710                183.7
#
# [1632 rows x 5 columns]

# %%
simplified.to_csv('municipalities.csv', index=False)
