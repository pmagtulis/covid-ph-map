# %% [markdown]
# # Cleaning Covid data for Mapbox
#
# **Background**: We us Covid-19 cases data in the Philippines from data from the health department and shapefile processed through geopandas to create an interactive map.
#
# **Tools**: pandas, geopandas, Mapbox

# %% [markdown]
# # Do your imports

# %%
import pandas as pd
import numpy as np
import geopandas as gpd
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Read your CSV

# %%
df= pd.read_csv('provinces-cases.csv')
df
# Out:
#     Unnamed: 0              ProvRes  CaseCode
# 0            0                 Abra      5933
# 1            1     Agusan Del Norte     22310
# 2            2       Agusan Del Sur     16476
# 3            3                Aklan     16217
# 4            4                Albay     13858
# ..         ...                  ...       ...
# 82          82            Tawi-Tawi       747
# 83          83             Zambales     20864
# 84          84  Zamboanga Del Norte     12615
# 85          85    Zamboanga Del Sur     46107
# 86          86    Zamboanga Sibugay      5511
#
# [87 rows x 3 columns]

# %% [markdown]
# # Cleaning the data
#
# ## Drop unnecessary columns

# %%
df= df.drop('Unnamed: 0', axis=1)
df
# Out:
#                 ProvRes  CaseCode
# 0                  Abra      5933
# 1      Agusan Del Norte     22310
# 2        Agusan Del Sur     16476
# 3                 Aklan     16217
# 4                 Albay     13858
# ..                  ...       ...
# 82            Tawi-Tawi       747
# 83             Zambales     20864
# 84  Zamboanga Del Norte     12615
# 85    Zamboanga Del Sur     46107
# 86    Zamboanga Sibugay      5511
#
# [87 rows x 2 columns]

# %% [markdown]
# ## Lowercase column headers

# %%
df.columns = df.columns.str.lower()
df.head(10)
# Out:
#             provres  casecode
# 0              Abra      5933
# 1  Agusan Del Norte     22310
# 2    Agusan Del Sur     16476
# 3             Aklan     16217
# 4             Albay     13858
# 5           Antique      9442
# 6            Apayao      9335
# 7            Aurora      4291
# 8           Basilan      1765
# 9            Bataan     41695

# %% [markdown]
# ## Clean provincial names
#
# This is so they would match the names in the shapefile for merging later.

# %%
df.provres = df.provres.str.replace("City Of Isabela (Not A Province)", "City of Isabela", regex=False)
df.provres = df.provres.str.replace("Cotabato (North Cotabato)", "Cotabato", regex=False)
df.provres = df.provres.str.replace("Ncr", "NCR", regex=False)
df.provres = df.provres.str.replace("Samar (Western Samar)", "Samar", regex=False)
df.provres = df.provres.str.replace("Cotabato City (Not A Province)", "Cotabato City", regex=False)
df.provres = df.provres.str.replace("Del", "del", regex=False)
df.provres = df.provres.str.replace("De", "de", regex=False)

# %% [markdown]
# ## Rename columns
#
# This is again to match the shapefile column containing the provinces' names which is 'adm2_en'. We are also renaming the column containing the Covid-19 cases tally.

# %%
df= df.rename(columns={"provres": "adm2_en"})
df= df.rename(columns={"casecode": "covid_cases"})
df
# Out:
#                 adm2_en  covid_cases
# 0                  Abra         5933
# 1      Agusan del Norte        22310
# 2        Agusan del Sur        16476
# 3                 Aklan        16217
# 4                 Albay        13858
# ..                  ...          ...
# 82            Tawi-Tawi          747
# 83             Zambales        20864
# 84  Zamboanga del Norte        12615
# 85    Zamboanga del Sur        46107
# 86    Zamboanga Sibugay         5511
#
# [87 rows x 2 columns]

# %% [markdown]
# # Geopandas
#
# ## Read through file

# %%
provinces = gpd.read_file('ph-provinces.zip')
provinces
# Out:
#     Shape_Leng  Shape_Area              ADM2_EN   ADM2_PCODE ADM2_REF  \
# 0     2.640967    0.334223                 Abra  PH140100000     None
# 1     3.674955    0.220065     Agusan del Norte  PH160200000     None
# 2     5.222636    0.693968       Agusan del Sur  PH160300000     None
# 3     4.626091    0.139664                Aklan  PH060400000     None
# 4     6.507665    0.205939                Albay  PH050500000     None
# ..         ...         ...                  ...          ...      ...
# 82   15.971439    0.094186            Tawi-Tawi  PH157000000     None
# 83    5.329770    0.313705             Zambales  PH037100000     None
# 84    8.170921    0.515482  Zamboanga del Norte  PH097200000     None
# 85   11.811347    0.439807    Zamboanga del Sur  PH097300000     None
# 86    8.997252    0.223408    Zamboanga Sibugay  PH098300000     None
#
#    ADM2ALT1EN ADM2ALT2EN                               ADM1_EN   ADM1_PCODE  \
# 0        None       None      Cordillera Administrative Region  PH140000000
# 1        None       None                           Region XIII  PH160000000
# 2        None       None                           Region XIII  PH160000000
# 3        None       None                             Region VI  PH060000000
# 4        None       None                              Region V  PH050000000
# ..        ...        ...                                   ...          ...
# 82       None       None  Autonomous Region in Muslim Mindanao  PH150000000
# 83       None       None                            Region III  PH030000000
# 84       None       None                             Region IX  PH090000000
# 85       None       None                             Region IX  PH090000000
# 86       None       None                             Region IX  PH090000000
#
#               ADM0_EN ADM0_PCODE        date     validOn validTo  \
# 0   Philippines (the)         PH  2016-06-30  2020-05-29    None
# 1   Philippines (the)         PH  2016-06-30  2020-05-29    None
# 2   Philippines (the)         PH  2016-06-30  2020-05-29    None
# 3   Philippines (the)         PH  2016-06-30  2020-05-29    None
# 4   Philippines (the)         PH  2016-06-30  2020-05-29    None
# ..                ...        ...         ...         ...     ...
# 82  Philippines (the)         PH  2016-06-30  2020-05-29    None
# 83  Philippines (the)         PH  2016-06-30  2020-05-29    None
# 84  Philippines (the)         PH  2016-06-30  2020-05-29    None
# 85  Philippines (the)         PH  2016-06-30  2020-05-29    None
# 86  Philippines (the)         PH  2016-06-30  2020-05-29    None
#
#                                              geometry
# 0   POLYGON ((120.96109 17.95348, 120.97201 17.946...
# 1   MULTIPOLYGON (((125.58886 9.45793, 125.59687 9...
# 2   POLYGON ((125.88961 8.98195, 125.88896 8.96446...
# 3   MULTIPOLYGON (((122.43980 11.59717, 122.43979 ...
# 4   MULTIPOLYGON (((124.20992 13.16871, 124.20993 ...
# ..                                                ...
# 82  MULTIPOLYGON (((119.46876 4.59360, 119.46881 4...
# 83  MULTIPOLYGON (((120.11687 14.76309, 120.11689 ...
# 84  MULTIPOLYGON (((122.09474 7.53104, 122.09482 7...
# 85  MULTIPOLYGON (((122.05710 6.87274, 122.05724 6...
# 86  MULTIPOLYGON (((122.84298 7.27985, 122.84299 7...
#
# [87 rows x 15 columns]

# %% [markdown]
# ## Merge data

# %%
provinces.columns = provinces.columns.str.lower()
provinces
# Out:
#     shape_leng  shape_area              adm2_en   adm2_pcode adm2_ref  \
# 0     2.640967    0.334223                 Abra  PH140100000     None
# 1     3.674955    0.220065     Agusan del Norte  PH160200000     None
# 2     5.222636    0.693968       Agusan del Sur  PH160300000     None
# 3     4.626091    0.139664                Aklan  PH060400000     None
# 4     6.507665    0.205939                Albay  PH050500000     None
# ..         ...         ...                  ...          ...      ...
# 82   15.971439    0.094186            Tawi-Tawi  PH157000000     None
# 83    5.329770    0.313705             Zambales  PH037100000     None
# 84    8.170921    0.515482  Zamboanga del Norte  PH097200000     None
# 85   11.811347    0.439807    Zamboanga del Sur  PH097300000     None
# 86    8.997252    0.223408    Zamboanga Sibugay  PH098300000     None
#
#    adm2alt1en adm2alt2en                               adm1_en   adm1_pcode  \
# 0        None       None      Cordillera Administrative Region  PH140000000
# 1        None       None                           Region XIII  PH160000000
# 2        None       None                           Region XIII  PH160000000
# 3        None       None                             Region VI  PH060000000
# 4        None       None                              Region V  PH050000000
# ..        ...        ...                                   ...          ...
# 82       None       None  Autonomous Region in Muslim Mindanao  PH150000000
# 83       None       None                            Region III  PH030000000
# 84       None       None                             Region IX  PH090000000
# 85       None       None                             Region IX  PH090000000
# 86       None       None                             Region IX  PH090000000
#
#               adm0_en adm0_pcode        date     validon validto  \
# 0   Philippines (the)         PH  2016-06-30  2020-05-29    None
# 1   Philippines (the)         PH  2016-06-30  2020-05-29    None
# 2   Philippines (the)         PH  2016-06-30  2020-05-29    None
# 3   Philippines (the)         PH  2016-06-30  2020-05-29    None
# 4   Philippines (the)         PH  2016-06-30  2020-05-29    None
# ..                ...        ...         ...         ...     ...
# 82  Philippines (the)         PH  2016-06-30  2020-05-29    None
# 83  Philippines (the)         PH  2016-06-30  2020-05-29    None
# 84  Philippines (the)         PH  2016-06-30  2020-05-29    None
# 85  Philippines (the)         PH  2016-06-30  2020-05-29    None
# 86  Philippines (the)         PH  2016-06-30  2020-05-29    None
#
#                                              geometry
# 0   POLYGON ((120.96109 17.95348, 120.97201 17.946...
# 1   MULTIPOLYGON (((125.58886 9.45793, 125.59687 9...
# 2   POLYGON ((125.88961 8.98195, 125.88896 8.96446...
# 3   MULTIPOLYGON (((122.43980 11.59717, 122.43979 ...
# 4   MULTIPOLYGON (((124.20992 13.16871, 124.20993 ...
# ..                                                ...
# 82  MULTIPOLYGON (((119.46876 4.59360, 119.46881 4...
# 83  MULTIPOLYGON (((120.11687 14.76309, 120.11689 ...
# 84  MULTIPOLYGON (((122.09474 7.53104, 122.09482 7...
# 85  MULTIPOLYGON (((122.05710 6.87274, 122.05724 6...
# 86  MULTIPOLYGON (((122.84298 7.27985, 122.84299 7...
#
# [87 rows x 15 columns]

# %%
provinces_cases = provinces.merge(df, on='adm2_en')
provinces_cases
# Out:
#     shape_leng  shape_area              adm2_en   adm2_pcode adm2_ref  \
# 0     2.640967    0.334223                 Abra  PH140100000     None
# 1     3.674955    0.220065     Agusan del Norte  PH160200000     None
# 2     5.222636    0.693968       Agusan del Sur  PH160300000     None
# 3     4.626091    0.139664                Aklan  PH060400000     None
# 4     6.507665    0.205939                Albay  PH050500000     None
# ..         ...         ...                  ...          ...      ...
# 81   15.971439    0.094186            Tawi-Tawi  PH157000000     None
# 82    5.329770    0.313705             Zambales  PH037100000     None
# 83    8.170921    0.515482  Zamboanga del Norte  PH097200000     None
# 84   11.811347    0.439807    Zamboanga del Sur  PH097300000     None
# 85    8.997252    0.223408    Zamboanga Sibugay  PH098300000     None
#
#    adm2alt1en adm2alt2en                               adm1_en   adm1_pcode  \
# 0        None       None      Cordillera Administrative Region  PH140000000
# 1        None       None                           Region XIII  PH160000000
# 2        None       None                           Region XIII  PH160000000
# 3        None       None                             Region VI  PH060000000
# 4        None       None                              Region V  PH050000000
# ..        ...        ...                                   ...          ...
# 81       None       None  Autonomous Region in Muslim Mindanao  PH150000000
# 82       None       None                            Region III  PH030000000
# 83       None       None                             Region IX  PH090000000
# 84       None       None                             Region IX  PH090000000
# 85       None       None                             Region IX  PH090000000
#
#               adm0_en adm0_pcode        date     validon validto  \
# 0   Philippines (the)         PH  2016-06-30  2020-05-29    None
# 1   Philippines (the)         PH  2016-06-30  2020-05-29    None
# 2   Philippines (the)         PH  2016-06-30  2020-05-29    None
# 3   Philippines (the)         PH  2016-06-30  2020-05-29    None
# 4   Philippines (the)         PH  2016-06-30  2020-05-29    None
# ..                ...        ...         ...         ...     ...
# 81  Philippines (the)         PH  2016-06-30  2020-05-29    None
# 82  Philippines (the)         PH  2016-06-30  2020-05-29    None
# 83  Philippines (the)         PH  2016-06-30  2020-05-29    None
# 84  Philippines (the)         PH  2016-06-30  2020-05-29    None
# 85  Philippines (the)         PH  2016-06-30  2020-05-29    None
#
#                                              geometry  covid_cases
# 0   POLYGON ((120.96109 17.95348, 120.97201 17.946...         5933
# 1   MULTIPOLYGON (((125.58886 9.45793, 125.59687 9...        22310
# 2   POLYGON ((125.88961 8.98195, 125.88896 8.96446...        16476
# 3   MULTIPOLYGON (((122.43980 11.59717, 122.43979 ...        16217
# 4   MULTIPOLYGON (((124.20992 13.16871, 124.20993 ...        13858
# ..                                                ...          ...
# 81  MULTIPOLYGON (((119.46876 4.59360, 119.46881 4...          747
# 82  MULTIPOLYGON (((120.11687 14.76309, 120.11689 ...        20864
# 83  MULTIPOLYGON (((122.09474 7.53104, 122.09482 7...        12615
# 84  MULTIPOLYGON (((122.05710 6.87274, 122.05724 6...        46107
# 85  MULTIPOLYGON (((122.84298 7.27985, 122.84299 7...         5511
#
# [86 rows x 16 columns]

# %% [markdown]
# ## Drop unnecessary columns

# %%
provinces_cases = provinces_cases.drop(['adm2_ref', 'adm2alt1en', 'adm2alt2en', 'adm0_en', 'shape_leng', 'shape_area', 'adm0_pcode', 'adm1_pcode', 'date', 'validon', 'validto'], axis=1)
provinces_cases
# Out:
#                 adm2_en   adm2_pcode                               adm1_en  \
# 0                  Abra  PH140100000      Cordillera Administrative Region
# 1      Agusan del Norte  PH160200000                           Region XIII
# 2        Agusan del Sur  PH160300000                           Region XIII
# 3                 Aklan  PH060400000                             Region VI
# 4                 Albay  PH050500000                              Region V
# ..                  ...          ...                                   ...
# 81            Tawi-Tawi  PH157000000  Autonomous Region in Muslim Mindanao
# 82             Zambales  PH037100000                            Region III
# 83  Zamboanga del Norte  PH097200000                             Region IX
# 84    Zamboanga del Sur  PH097300000                             Region IX
# 85    Zamboanga Sibugay  PH098300000                             Region IX
#
#                                              geometry  covid_cases
# 0   POLYGON ((120.96109 17.95348, 120.97201 17.946...         5933
# 1   MULTIPOLYGON (((125.58886 9.45793, 125.59687 9...        22310
# 2   POLYGON ((125.88961 8.98195, 125.88896 8.96446...        16476
# 3   MULTIPOLYGON (((122.43980 11.59717, 122.43979 ...        16217
# 4   MULTIPOLYGON (((124.20992 13.16871, 124.20993 ...        13858
# ..                                                ...          ...
# 81  MULTIPOLYGON (((119.46876 4.59360, 119.46881 4...          747
# 82  MULTIPOLYGON (((120.11687 14.76309, 120.11689 ...        20864
# 83  MULTIPOLYGON (((122.09474 7.53104, 122.09482 7...        12615
# 84  MULTIPOLYGON (((122.05710 6.87274, 122.05724 6...        46107
# 85  MULTIPOLYGON (((122.84298 7.27985, 122.84299 7...         5511
#
# [86 rows x 5 columns]

# %% [markdown]
# # Save as GEOJSON file

# %%
provinces_cases.to_file('provinces_cases.geojson', driver='GeoJSON')
# Out:
# /Users/prinzmagtulis/.pyenv/versions/3.10.0/lib/python3.10/site-packages/geopandas/io/file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
